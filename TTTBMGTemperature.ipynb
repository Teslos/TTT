# %% [markdown]
# In this simulation we are calculating TTT and CCT diagrams for following the cooling behaviour of the AMZ4 and BMG.
# The current notebook follows presentation given by A.Malakizadi:
#
# Diploma work No. 42/2010
# at Department of Materials and Manufacturing Technology
# CHALMERS UNIVERSITY OF TECHNOLOGY
# Gotheburg Sweden
#
# The simulation is extend to the simulation and formulation of the nucleation of the crystallites in BMG-s as described in:
# "Transient nucleation in selective laser melting of Zr-based bulk metallic glass" Materials & Design,195,108958,(2020).
#
# Note this is applied to BMG material AMZ4.

# %% [markdown]
# # Constitutive equation and finite element formulation

# %% [markdown]
# Heat equation is given here in the general form to model also the phase transformations during the phase transformations of the alloy:

# %% [markdown]
# Conservation of the energy is given by the equation:
# $$
# \rho \frac{\partial E}{\partial t} - \nabla(k\nabla T)= 0
# $$
# where the E is specific internal energy. $ \rho, k$ and $T,t$ are density, thermal conductivity, temperature and time.
# Specific internal energy can also be represented using:
# $$
# E(t,x)= e(T,X_i)
# $$
# where $ X_i $ for $i={1,2,3,4}$ are volume fraction for example of the perlite, bainite, ferrite and martensite phase.
# Differenting the $e(T,X_i)$ with the respect to internal variables:
# $$
# \frac{\partial e}{\partial T} = c_p \\
# \frac{\partial e}{\partial X_i}=-q_i
# $$
# Thus the general equation is given by:

# %% [markdown]
# $$
# \rho(T)c_p(T)\frac{\partial T}{\partial t}=\frac{\partial }{\partial x}(k(T)\frac{\partial T}{\partial x}) +
# \frac{\partial }{\partial y}(k(T)\frac{\partial T}{\partial y})+\frac{\partial }{\partial z}(k(T)\frac{\partial T}{\partial z})
# +\sum{\rho_i(T)q_i(T) \frac{\partial X_i}{\partial t}}
# $$

# %% [markdown]
# It is important to set also the correct boundary conditions and initial boundary conditions  for the cooling:

# %% [markdown]
# Cooling condition for radiation and air convection:
# $$
# -k\frac{\partial T}{\partial n} = h_c(T) (T-T_{\infty})+\sigma\epsilon(T)(T^{4}-T^{4}_\infty)
# $$
# If we are cooling by water or quenching:
# $$
# -k\frac{\partial T}{\partial n} = h_q(T) (T-T_{\infty})
# $$
# And the start temperature of the sample is given:
# $$
# T_0 = T(x,y,0)
# $$
# here the $h_c(T)$ is the convective heat transfer coefficient, $\sigma$ is the Stefan-Boltzmann constant, and $\epsilon $ is radiation emissivity of the surface and $T_\infty$ is the sorounding temperature.
# It is possible to reduce the surface radiation to:
# $$
# \sigma \epsilon(T) (T^4-T^4_\infty)= \sigma \epsilon(T)(T^2+T^2_\infty)(T+T_\infty)(T-T_\infty)=h_r(T)(T-T_\infty)
# $$
# So combined radiation and convection boundary condition can be expressed by:
# $$
# -k\frac{\partial T}{\partial n}=h_r(T)(T-T_\infty)+h_c(T) (T-T_{\infty})=h_{rc}(T)(T-T_{\infty})
# $$
# where $h_{rc}$ is combined heat transfer.

# %% [markdown]
# $$
# \rho(T)c_p(T) \frac{\partial T}{\partial t} =k(T)\left( \frac{1}{r}  \frac{\partial }{\partial r}(r\frac{\partial T}{\partial r})+ \frac{\partial^2 T}{\partial z^2}\right)+\sum{\rho_i(T)q_i(T)\frac{\partial X_i}{\partial t}}
# $$

# %% [markdown]
# ## Incoperation of the phase transformation terms

# %% [markdown]
# Phase transformation in weak formulation for the phase transformation.
# $$
# R = \int_{\Gamma}{w rh_{rc} T_\infty}+\int_{\omega} w\sum{\rho_i q_i \frac{\partial X_i}{\partial t} rdrdz}
# $$
# At constant pressure is the latent heat of transformations are equal to entalphy changes $\rho q_i = \Delta H_i$
#
# $$
# R=\int_{\Gamma}{w rh_{rc} T_\infty}+\int_{\omega} w\sum{\Delta H_i \frac{\partial X_i}{\partial t} rdrdz}
# $$
# Time derivative can be approximated:
# $$
# \frac{\partial X_i}{\partial t} = \frac{\Delta X_i}{\Delta t}=\frac{X_i^{j+1}-X_i^{j}}{\Delta t}
# $$
# where $X^{j+1}_i$ is the volume fraction of the phase $i$ at time $j+1$. The thermal properties of the mixture are calculated
# using the mixture rule:
# $$
# \rho c_p = \sum{X_i\rho_i c_{p_i}} \\
# k = \sum{X_i k_i}
# $$
# Both models JMAK and AR model can be used to calculate the amount of the diffusive transformation. We focus now on the JMAK model.

# %% [markdown]
# # Scheil principle

# %% [markdown]
# The kinetics of the transformation during cooling (anisothermal condition) according to Scheil principle can the approximated by means of infinitesimal time increments $\Delta t$ and ficitious time $t^{*}$ need to gain same fraction of phase $i$ at the current temperature $T_j$

# %% [markdown]
# $$
# t_j = \Delta t + t_j^{*}
# $$
# where we can calculate $t^{*}$ from JMAK model as:
# $$
# t_j^{*} = \left [ \frac{ln(\frac{1}{1-X_{i,j-1}})}{k(T_j)}\right]^{1/n(T_j)}
# $$
# In the case of the remaining austenite phase we should correct $X_{i,j-1}$ with:
# $$
# F_{i,j-1}=\frac{X_{i,j-1}}{X_{i,j-1}+X_{\gamma,j-1}}
# $$
# then previous equation is written as:
# $$
# t_j^{*} = \left [ \frac{ln(\frac{1}{1-F_{i,j-1}})}{k(T_j)}\right]^{1/n(T_j)}
# $$
# This equation is valid for the experimentaly measured TTT diagram in the case of the BMG
# we use the Kissinger analysis to calculate the JMAK parameters:
# $$
# t_j^{*} = \left [ \frac{ln(\frac{1}{1-F_{i,j-1}})}{k_0 \exp(\frac{-E}{kT_j})}\right]^{1/n(T_j)}
# $$
# where now $$ k(T_j) = k_0 \exp(\frac{-E}{kT_j})$$
# So we can calculate then the fictious volume fraction of phase $i$ at time $j$:
# $$
# F_{i,j}^{*}=1-exp\left(-k(T_j)t_j^{n(T_j)} \right)
# $$
# The incubation time of the diffusive transformation are calculated using equation:
# $$
# Q = \int_{0}^{t} \frac{d\epsilon}{\tau_s(T(\epsilon))}= \sum\frac{\Delta t}{\tau_s(T_j)}
# $$

# %% [markdown]
# ## Test case

# %% [markdown]
# For this test case we are using the data available from the thesis "Modeling of Bulk Metallic Glass formation
# in Powder Bed Fusion" by John Lindwall from http://www.ltu.se ISBN 978-91-7790-306-2
#
# Specific heat is modelled as function it is taken from the thesis and it is based on the data measured in the
# paper Heinrich et al.

# %%
def h(T):
    a = 5.225E-4
    b = 1.031E+7
    R = 8.134
    c = 0.00623
    d = -6.047E-7
    if (T <= (470+273)):
        return 3*R + c * T + d * T**(-2)
    elif ( (470+273) < T < (1200+273) ):
        return 3*R + a * T + b * T**(-2)
    return 0

# %% [markdown]
# Plot the cp (specific heat) of the alloy to see if the function correspond to experimental data:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
temp = []
cp = []
rhoAMZ4 = 76.595E-3

for step in range(1,1200):
    val = h(step+273)/rhoAMZ4
    cp.append(val)
    temp.append(step+273)
plt.plot(temp,cp)
plt.show()

# %%
cp[470+273]-cp[471+273]
# Out:
# 0.2487338849102798

# %%
rho=6.7
omega=4.20E-6
def kAMZ4(T):
    return h(T) * rho * omega

# %%
kam = []
temp = []
for step in range(1,1200):
    val = kAMZ4(step)/rhoAMZ4
    kam.append(val)
    temp.append(step+273)
plt.plot(temp,kam)
plt.show()

# %% [markdown]
# ## Note this is the test case for the PM steels
# Assuming that the Jominy test can be treated as the semi-infinite plate. The surface exposed to convective boundary condition exposed on one side, the analytical solution is given as:
# $$
# \frac{T(x,t)-T_i}{T_{\infty}-T_i}=erfc \left(\frac{x}{2\sqrt{\alpha t}}\right) - exp\left(\frac{h x }{k}+\frac{h^2 \alpha t }{k^2}\right)
# erfc\left(\frac{x}{2\sqrt{\alpha t}} + \frac{h\sqrt{\alpha t} }{k}\right)
# $$
# The temperature distribution of the bar at different position $x$ and time $t$ can be obtained if we know distribution of temperature $T$ at previous time step $t_{i-1}$.

# %%
rho=6200; Cp=500.0; k=20.0; alpha=k/(Cp*rho)
import math
def T(x,t,T):
    return math.erfc(x/(2*math.sqrt(alpha*t)))-math.exp(h(T)*x/k + (h(T)**2 * alpha * t/(k**2))) * math.erfc(x/(2*math.sqrt(alpha*t))+h(T)*math.sqrt(alpha*t)/k)

# %% [markdown]
# Here we calculate the temperature drop from the one dimensional solution described in previous cell, we set initial temperature of the bar to $T=1173$ K:

# %%
t_initial=900.0+273; t_inf=23.0+273
tr=t_initial
temp=[]
for step in range(1,200):
    a=T(0.0,step,tr)
    tr = a*(t_inf-t_initial)+t_initial
    temp.append(tr)

# %% [markdown]
# Plot the given temperature for position $x=0$

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(temp)
plt.show()

# %% [markdown]
# # Calculation of heat transfer

# %% [markdown]
# In this section we solve general 2d heat equation using fipy library.

# %%
from fipy import *
import numpy as np

# %% [markdown]
# ## Material properties

# %% [markdown]
# Here we define the material properties for the AMZ4 bulk metallic glass. The data are taken from the thesis "Modeling of Bulk Metallic glass formation in Powder Bed Fusion" by Johan Lindwall.
# Data are saved in the text file for reading.
# Density is taken from the paper I.Jonas W.Hembree,F.Yang,R.Busch, and A.Meyer, Appl.Phys.Lett. 112, 171902 (2018)

# %%
def densityAMZ4(T):
    return 6.82 - 3.48E-4 * T # density in g/cm^3

# %% [markdown]
# Interpolate the experimental data to get interpolating function:

# %% [markdown]
# In this section we are reading the data from the Kissinger analysis to evaluate the values of the material parameters $k(T_j)$ and $n(T_j)$. Using the previous equations we can calculate the value of $k(T_j)$:
# $$
# k(T_j)=k_0 \exp(-E/kT_j)
# $$
# and
# $$
# n(T_j)= const
# $$
# This data are used to describe very restricted region of the TTT diagram and thus are not usable for the phase transformations which are at higher temperatures and shorter times.

# %%
k0 = 9.49E+7
E = 88.8E+3
Rt = 8.314 # universal gas constant
def calcn(temperature):
    #for now the n is temperature independent    
    return 1.49
          
def calck(Fs,temperature):
    #determine k
    return -np.log(1-Fs)/(k0*np.exp(-E/(Rt*temperature)))
    
k=calck(0.005,693) #test calculations
k
# Out:
# 0.00026079750161274424

# %% [markdown]
# In this section we are reading the data from experimental TTT diagram to evaluate the values of the material parameters $k(T_j)$ and $n(T_j)$. Using the previous equations we can calculate the value of $k(T_j)$:
# $$
# k(T_j)=-ln(1-F_s)/\theta_j^{n(T_j)}
# $$
# and
# $$
# n(T_j)=\frac{ln(\frac{ln(1-F_s)}{ln(1-F_e)})}{ln(\frac{\theta_s}{\theta_e})}
# $$
# where $\theta$ repesents the equivalent transformation time. $F_s$ and $F_e$ are start fraction of the phase and end fraction of the phase, repectively (usually defined $F_s=0.005$ and $F_e=0.995$).
#
# In this code we first read the experimental data to arrays and then fit x and y data with cubic spline. This gives us information for complete temperature range. The values of $k(T_j)$ and $n(T_j)$ are then calculate using the previous equations.

# %%
# curve fitting
from scipy.optimize import curve_fit, fsolve, newton
from scipy.interpolate import RectBivariateSpline, CubicSpline

def read_ttt():
    amz4 = np.loadtxt(fname='./TTT_AMZ4.txt', comments='#', delimiter=',', dtype='double')
    amz4_99 = np.loadtxt(fname='./TTT_AMZ4_99.txt', comments='#', delimiter=',', dtype='double')
    return (amz4,amz4_99)


(amz4_line,amz4_line_99) = read_ttt()

# interpolate using the cubic spline
amz4spl=CubicSpline(amz4_line[:,1],amz4_line[:,0])
amz4spl_99=CubicSpline(amz4_line_99[:,1],amz4_line_99[:,0])
wt = np.linspace(600,1160,50)
figp, axp = plt.subplots()
axp.semilogy(wt, amz4spl(wt))
axp.semilogy(wt, amz4spl_99(wt))
axp.semilogy(np.flipud(amz4_line[:,1]),np.flipud(amz4_line[:,0]))
axp.set_title('TTT diagram')
axp.set_xlabel('Temperature C')
axp.set_ylabel('Time s')
def calcn(Fs, Fe, startspl, endspl, temperature):
    #determine theta for different temperature
    thetas = startspl(temperature)
    thetae = endspl(temperature)
    return np.log(np.log(1-Fs)/np.log(1-Fe))/np.log(thetas/thetae)

n=calcn(0.05,0.995,amz4spl,amz4spl_99,wt) #test calculations
def calck(Fs,n,startspl, temperature):
    #determine k
    thetas = startspl(temperature)
    return -np.log(1-Fs)/(thetas**n)
    
k=calck(0.05,n,amz4spl,wt) #test calculations

# %%
n
# Out:
# array([3.21574099, 3.1603619 , 3.09986804, 3.11943024, 3.7719873 ,
#        3.05924641, 3.50794602, 3.78350117, 3.26697594, 4.10405095,
#        3.71397823, 3.5443398 , 3.52865304, 3.68901955, 3.95999585,
#        3.60412527, 3.75646641, 3.70659911, 3.92285189, 3.65917704,
#        3.6393308 , 3.77930343, 3.76583749, 3.6912495 , 3.72335049,
#        3.70760689, 3.67861446, 3.71543665, 3.78152236, 3.80113521,
#        3.81519563, 3.83353462, 3.82004298, 3.78234413, 3.7463634 ,
#        3.72782629, 3.73692303, 3.74077924, 3.74373541, 3.79826197,
#        3.65282305, 3.65891696, 3.5424872 , 3.66206272, 3.83004345,
#        3.51460996, 3.81002198, 4.07103895, 2.22464425, 1.85702167])

# %%
def jmak(k,n,t):
    x = 1 - np.exp(-k*t**n)
    return x

xs = jmak(k[30],n[30],0.001)
print(xs)
print(wt[30])
figj, axj = plt.subplots()
axj.plot(xs)
# Out:
# 7.408325900515322e-07
# 942.8571428571429

# %% [markdown]
# # Heat transfer calculation

# %% [markdown]
# Define some common mesh values for 2D heat flow. We create uniform cylinder mesh on which we solve axisymmetric case.

# %%
steps = 100
N = 320
L = 0.25/4.0*N/4000  # this is now in meters and it is about 2.5 mm
dL = L / N
dt = 1e-3
mesh = CylindricalGrid2D(dx = dL, dy = dL, nx = N, ny = N)

# %% [markdown]
# Also adds the fraction of different phases as cell variable, so we can calculate the contributions from different phases to heat equation.

# %%
fi = CellVariable(mesh=mesh, name='frac. amorphous', hasOld=True, value=0.0)
fc = CellVariable(mesh=mesh, name='frac. crystalline', hasOld=True, value=0.0)
xi = CellVariable(mesh=mesh, name='volume fract.',hasOld=True, value=0.)
temperature = CellVariable(mesh = mesh, name='temperature',value=293., hasOld=True)
tincubation = CellVariable(mesh = mesh, name='incubation', value=0., hasOld=True)
laserSource = CellVariable(mesh = mesh, name='source', value=0.)
n = CellVariable(mesh = mesh, name='jmak exponent', value=0.)
k = CellVariable(mesh = mesh, name='jmak coeff', value=0.)
(r,z) = mesh.cellCenters()

# %% [markdown]
# Initial temperature of the cylinder and surface is set to:
# $T_o= 293$.
# Boundary condition at $y=0$ is given by surface heating condition:
# $$
# -k \frac{\partial T}{\partial n} = q
# $$
# where q is given as the flux of the laser on the surface:
# $$
# q = Q exp((-2*(x-x_0)^2+(y-y_0)^2)/r_o^2)
# $$
# The boundary condition on the $x=0$ left side of the domain is isolated:
# $$
# -k \frac{\partial T}{\partial n} = 0
# $$
# The temperature on the top and right side of cylinder are set to surounding temperature:
# $T_0 = T_{\infty}$

# %% [markdown]
# ## Implementation of the body source
# For the source we implement the body source according to Goldak source:
# $$
# q = Q exp (-3 * (2(r-r_0)^2/\omega_0^2+(z-z_0)^2/c^2))
# $$
# where
# $$
# Q = \frac{6\sqrt{3}P\eta f}{\omega^2_0 c \pi\sqrt{\pi}}
# $$
# this is currently implemented as the source heat in this script

# %%
from fipy.tools.numerix import sqrt, exp, pi
# function parameters:
# r-radius coordinate
# z-depth coordinate
# r0,z0 - laser coordinates
# omega0 - spot size of the laser
# c - depth of the laser pool
# power - laser power
def qlaser(r,z,r0,z0,omega0,c,power):
    Q = 6*sqrt(3)*power/(pi*sqrt(pi)*c*omega0**2)
    return Q * exp(-3 * (2*((r-r0)/omega0)**2+((z-z0)/c)**2) )

# %%
qlaser(r,z,0,0,0.1,0.01,100)
# Out:
# array([1866320.63375009, 1866320.08697655, 1866318.99342994, ...,
#         870703.44480385,  870622.33031223,  870540.96833588])

# %%
t_inf = 293
#vh = np.vectorize(h)
#temperature.faceGrad.dot([0,1]).constrain(-vh(temperature.faceValue)*1/k*(temperature.faceValue-t_inf),mesh.facesBottom)
temperature.faceGrad.dot([0,1]).constrain(0,mesh.facesBottom)
temperature.faceGrad.dot([1,0]).constrain(0,mesh.facesLeft)
temperature.constrain(293, mesh.facesRight)
#temperature.constrain(1173., mesh.facesTop)

# %% [markdown]
# Calculation of the transformation time (incubation time) before start of diffusive reaction:

# %%
def transformation_time(fc,k,n):
    return (np.log(1./(1.-fc)) / k)**(1./n)
def volume_fraction(time,k,n):
    fc.setValue(1-np.exp(-k *time**n), where= tincubation > 1.)

# %%
transf = []
temp = []
for step in range(1,1200):
    kt = k0*np.exp(-E/(Rt*(step+273)))
    val = transformation_time(0.95,kt,n)
    transf.append(val)
    temp.append(step+273)
plt.loglog(transf,temp)
plt.show()
# Out:
# C:\Users\tonii\Anaconda2\envs\idp\lib\site-packages\fipy\variables\variable.py:1148: RuntimeWarning: divide by zero encountered in true_divide
#   return self._BinaryOperatorVariable(lambda a, b: b / a, other)
# C:\Users\tonii\Anaconda2\envs\idp\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Data has no positive values, and therefore cannot be log-scaled.

# %% [markdown]
# Define the source term for the phase transformation effects. The phase transformation source contains the fraction of the amorphous phase transformed in crystalline and enthalpy of the formation.
# Singh and Dubey expressed the difference of specific heat between the undercooled liquid and the crystalline state:
# $$
# \Delta C_p = C_{p,m}(\frac{T_m}{T})^2\exp(-\sigma_D\frac{\Delta T}{T})
# $$
# where:
# $$
# \sigma_D = \frac{T_g}{T_m-T_g}\ln((\frac{T_m}{T_g})^2 \frac{\Delta C_{p,m}}{\Delta C_{p,g}})
# $$

# %%
Tg=470+273
Tm=920+273
deltaCpm = 20.18 # specific heat difference at melting J/g
deltaCpg = 13.3 # specific heat diff. at glass transition J/g
sigmaD = Tg/(Tm-Tg) * np.log((Tm/Tg)**2 * deltaCpm/deltaCpg)
def deltaCp(T,deltaT):
    return deltaCpm*(Tm/T)**2 * np.exp(-sigmaD * deltaT/T)
def phaseSourceT(temp):
    return TransientTerm(var=fi,coeff=deltaCp(temp,Tm-temp))+TransientTerm(var=fc,coeff=deltaCp(temp,Tm-temp))

# %% [markdown]
# Now setup the temperature equation for source term comming from the phase transformations defined the flag phaseTrans.
# Here we added also same flux from the right side of the cylinder, assuming that the cooling liquid is also hitting the right side of cylinder.

# %%
rho = 6820 # for now the density is constant in temperature equation kg/m**3
Cp = 500 # for now this is the constant value only for testing
kv = np.vectorize(kAMZ4)

def kM(T):
    a = 5.225E-4
    b = 1.031E+7
    R = 8.134
    c = 0.00623
    d = -6.047E-7
    return 3*R + c * T + d * T**(-2)

laserSource.setValue(qlaser(r,z,0,0,0.001,0.0005,100))
temperatureEq = TransientTerm(coeff=rho*Cp,var=temperature) == DiffusionTerm(coeff=20,var=temperature) + \
laserSource

# %%
temperature.shape
# Out:
# (102400,)

# %%
if __name__ == '__main__':
    temperatureViewer = Viewer(vars=temperature,figaspect=1,datamin=0,datamax=1200)
# Out:
# C:\Users\tonii\Anaconda2\envs\idp\lib\site-packages\fipy\viewers\matplotlibViewer\matplotlibViewer.py:229: MatplotlibDeprecationWarning:
# The set_norm function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_norm instead.
#   self._cb.set_norm(value)

# %% [markdown]
# We step the solution in time, plotting as we go interactively

# %%
import fipy.solvers.pyAMG as solvers
#import fipy.solvers.pysparse as solvers
import numpy as np
solver = solvers.linearGMRESSolver.LinearGMRESSolver(precon=None, iterations=1500, tolerance=1e-15) 
poisson= solvers.linearLUSolver.LinearLUSolver()

steps = 100 # number of steps to calculate
eps =1e-5
Tvstime = [] # temperature values during cooling

for i in range(steps):
    terr=10e+10
    temperature.updateOld()
    fi.updateOld()
    fc.updateOld()
    
    # calculate incubation time
    n = calcn(0.005,0.99,amz4spl, amz4spl_99, temperature)
    k = calck(0.005,n,amz4spl,temperature)
    print ("n = {} and k = {}".format(n,k))
    print ("crystalline fraction: {}".format(fc))
    tt = transformation_time(fc,k,n)
    #kt = k0*np.exp(-E/(Rt*temperature))
    print ("full transformation time: {}".format(transformation_time(0.05,k,n)))
    tincubation.setValue(tincubation.value + (dt+tt)/transformation_time(0.05,k,n))
    print (tincubation)
    # calculate volume fraction of the crystalline phase
    # the reaction start when incubation time reaches 1.0
    volume_fraction(tt+dt,k,n) 
        
    # update martensite fraction using koistinen-marburger eq.
    # koistinen_marburger(temperature) 
    # update complete volume fraction
    xi = fc + fi
    print (max(xi))
    while(terr > eps):
        print ("Residual %f" % terr)
        terr = temperatureEq.sweep(temperature, dt=dt,solver=poisson)
    
    #print min(phaseSourceT())
    if __name__ == '__main__':
        path = "E:/TEST/temperature/"
        temperatureViewer.plot(path+"temperatureBMG"+str(i)+".eps")  
        np.savetxt(path+"temperatureBMG"+str(i),temperature)
        np.savetxt(path+"amorphousBMG"+str(i),fi)
        np.savetxt(path+"crystallineBMG"+str(i),fc)
        Tvstime.append(temperature.value[0])
        print ("step: ", i, "Min. temperature",min(temperature), "Max. temperature", max(temperature))
# Out:
# step:  99 Min. temperature 293.0000000060772 Max. temperature 1229.9983356298055

# %%
viewerTemperature = Matplotlib2DGridViewer(vars=temperature, title = '$temperature$')
# Out:
# C:\Users\tonii\Anaconda2\envs\idp\lib\site-packages\fipy\viewers\matplotlibViewer\matplotlibViewer.py:229: MatplotlibDeprecationWarning:
# The set_norm function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_norm instead.
#   self._cb.set_norm(value)

# %% [markdown]
# # Visualize the results

# %%
fig1, (axp2, axc2)= plt.subplots(2, 1, sharex=False, sharey=False, figsize=(14,10))

viewer1 = MultiViewer(viewers = (Matplotlib2DGridViewer(vars=fi, title='$amorphous$', axes=axp2, \
                                                       datamin=0., datamax=1000.), \
                                Matplotlib2DGridViewer(vars=fc,  title='$crystalline$'   , axes=axc2, \
                                                       datamin=0., datamax=.1)))
# Out:
# C:\Users\tonii\Anaconda2\envs\idp\lib\site-packages\fipy\viewers\matplotlibViewer\matplotlibViewer.py:229: MatplotlibDeprecationWarning:
# The set_norm function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_norm instead.
#   self._cb.set_norm(value)

# %%
load=np.loadtxt(path+"temperatureBMG99")
fig,ax = plt.subplots()
ax.contourf(load.reshape(N,N))

# %%
# %matplotlib inline
temperatureViewer.plot(path + "temperature100.png")

# %% [markdown]
# Plotting the value of the temperature in the middle of the cylinder at the convection surface.

# %%
t=[]
t1=[]
for i in range(1,100,1):
    load = np.loadtxt(path+"temperatureBMG"+str(i))
    t.append(load.reshape(N,N)[5,1])
    t1.append(load.reshape(N,N)[20,20])
fig, ax = plt.subplots()
ax.plot(t)
ax.plot(t1)
ax.set(title='Temperature',ylabel='Temperature K',xlabel='timesteps')
# Out:
# [Text(0, 0.5, 'Temperature K'),
#  Text(0.5, 0, 'timesteps'),
#  Text(0.5, 1.0, 'Temperature')]

# %% [markdown]
# Plot of the temperature at central point of the cylinder. The temperature rises on the point and then drops again due to enthalphy of austinite to martensite phase transformation. Is this numerical instability??

# %%
cry = []
cry1 = []
for i in range(1,54,2):
    load = np.loadtxt(path+"crystallineBMG"+str(i))
    cry.append(load.reshape(N,N)[5,1])
    cry1.append(load.reshape(N,N)[20,20])
fig, ax = plt.subplots()
ax.plot(cry)
ax.plot(cry1)
ax.set(title='Crystalline',ylabel='amount %',xlabel='timesteps')
# Out:
# [Text(0, 0.5, 'amount %'),
#  Text(0.5, 0, 'timesteps'),
#  Text(0.5, 1.0, 'Crystalline')]

# %%
point = []
for i in range(1, 54,2):
    load = np.loadtxt(path+ "amorphousBMG"+str(i))
    point.append(load.reshape(N,N))

# %% [markdown]
# ### Crystalline and amorphous amounts at end of simulation

# %%
fig2, (axp22, axc22)= plt.subplots(2, 1, sharex=False, sharey=False, figsize=(14,10))

axp22.plot(fi.value.reshape(N,N)[2,:], 'r')
axp22.plot(fc.value.reshape(N,N)[2,:], 'b')
axp22.set_xlabel('Radius')
axp22.set_ylabel('Amount of phase %')
axp22.set_title('Amount of crystalline (blue) and amorph (red) phases')

axc22.plot(fi.value.reshape(N,N)[:,20], 'r')
axc22.plot(fc.value.reshape(N,N)[:,20], 'b')
axc22.set_xlabel('Height')
axc22.set_ylabel('Amount of phase %')
axc22.set_title('Amount of crystalline (blue) and amorph (red) phases')
# Out:
# Text(0.5, 1.0, 'Amount of crystalline (blue) and amorph (red) phases')

# %% [markdown]
# # Temperature profile from FEM program

# %% [markdown]
# In this case we are reading the temperature profile from the FEM simulations with AMZ4. Profiles represent particular temperatures at chosen points (similar to thermocouples). For this particular temperatures we are calculating the amount of the crystalline phase.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.loadtxt('TemperatureNoWaiting_#3716.txt')

# %% [markdown]
# data = pd.read_excel('X1_Simulation results-v2.xlsx',sheet_name='L2_Depth', usecols = "A:T")

# %%
print(data)
# Out:
# [[0.00000e+00 2.98000e+02]
#  [1.00000e-03 2.98000e+02]
#  [2.00000e-03 2.98000e+02]
#  ...
#  [7.77951e-01 4.54872e+02]
#  [7.77963e-01 4.54863e+02]
#  [7.77975e-01 4.54854e+02]]

# %%
nl = 2358
# convert to Kelvins
temperature_read = data[:,1]
time = data[:,0]

# %%
# Out:
# array([0.      , 0.001   , 0.002   , ..., 0.777951, 0.777963, 0.777975])

# %%
fig,ax = plt.subplots()
ax.plot(time,temperature_read)
ax.set_xlabel('Time(s)')
ax.set_ylabel('Temperature (K)')
fig.show()
# Out:
# C:\Users\tonii\Anaconda2\envs\idp\lib\site-packages\matplotlib\figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
from math import log,exp
def transformation_time_read(fc,k,n):
    #print("fc: {},k:{},n:{}".format(fc,k,n))
    tim = (log(1./(1.-fc)) / k)**(1./n)
    #print("transformation time: {}".format(tim))
    return tim

def volume_fraction_read(time,k,n,incubation):
    fc = 0
    #print("Volfrac: Time: {}, k: {}, n: {}".format(time,k,n))
    if (incubation > 1.0):
        fc = (1-exp(-k *time**n))
        #print("fraction crystall: {}".format(fc))
    return fc

# %%
#for j in range(2,11):
#fcr = np.zeros(len(time))
fcr = 0.0
# incubation time to do reaction
tincubationr = 0
# transformation time
ttall = 0
temperature_read = data[:,1]
for j in range(10):
    for i in range(len(time)):
        if (i < len(time)-1):
            dt = time[i+1]-time[i]
            #print("dt: {}".format(dt))
            # calculate incubation time
        if(temperature_read[i] > 600 and temperature_read[i] < 1160):
            n = calcn(0.05,0.995,amz4spl, amz4spl_99, temperature_read[i])
            k = calck(0.05,n,amz4spl,temperature_read[i])
            #print ("T = {}, n = {} and k = {}".format(temperature_read[i],n,k))
            #print ("crystalline fraction: {}".format(fcr))
            tt = transformation_time_read(fcr,k,n)
            #print ("full transformation time: {} and fictious time: {}".format(transformation_time_read(0.01,k,n),tt))
            #this is extrapolation for 1% crystalline phase
            #tincubationr =  tincubationr + (dt)/transformation_time_read(0.01,k,n)
            # currently we are using the TTT-diagram which at 5% crystalline phase
            tincubationr =  tincubationr + (dt)/amz4spl(temperature_read[i+1])
            ttall = ttall + tt/transformation_time_read(0.01,k,n)
            #print ("Incubation time:{}" .format(tincubationr))
            # calculate volume fraction of the crystalline phase
            # the reaction start when incubation time reaches 1.0
            fcr = fcr + volume_fraction_read(tt+dt,k,n,tincubationr)
            fcr = 0.99 if fcr > 1.0 else fcr
            
                #print("New crystalline fraction:{}".format(fcr))
        
            print("Time incubation: {} for column: {}".format(tincubationr,data[i]))
            #print("Relative time: {} for column: {}".format(ttall,data[:,j]))
            #print("Crystalline volume: {} for column: {}".format(fcr, data[i]))
#np.sum(fcr)
# Out:
# Time incubation: 6.616030237088795e-11 for column: [  0.693295 600.608   ]
# Time incubation: 7.472914950341522e-09 for column: [  0.693312 643.627   ]
# Time incubation: 5.612932217765357e-08 for column: [  0.693329 685.346   ]
# Time incubation: 4.698075363414043e-07 for column: [6.93341e-01 7.10244e+02]
# Time incubation: 2.7135739153522718e-06 for column: [6.93354e-01 7.35581e+02]
# Time incubation: 1.619046041285674e-05 for column: [6.93366e-01 7.62729e+02]
# Time incubation: 6.597337422593742e-05 for column: [6.93379e-01 7.92815e+02]
# Time incubation: 0.00020430529223019786 for column: [6.93391e-01 8.23776e+02]
# Time incubation: 0.0004977112974229201 for column: [6.93404e-01 8.52843e+02]
# Time incubation: 0.0009600177974377121 for column: [6.93417e-01 8.80888e+02]
# Time incubation: 0.0016395626937139004 for column: [6.93429e-01 9.08751e+02]
# Time incubation: 0.0023342000510571947 for column: [6.93442e-01 9.38002e+02]
# Time incubation: 0.003275585956047287 for column: [6.93454e-01 9.65386e+02]
# Time incubation: 0.003841513655440796 for column: [6.93473e-01 1.00034e+03]
# Time incubation: 0.004085419123373921 for column: [6.93492e-01 1.03014e+03]
# Time incubation: 0.004194419621413522 for column: [6.93510e-01 1.05786e+03]
# Time incubation: 0.00423603132752102 for column: [6.93529e-01 1.07837e+03]
# Time incubation: 0.0042567002520868145 for column: [6.93543e-01 1.08924e+03]
# Time incubation: 0.004268387200270075 for column: [6.93557e-01 1.09875e+03]
# Time incubation: 0.004275851668016518 for column: [6.93571e-01 1.10641e+03]
# Time incubation: 0.004281894338876871 for column: [6.93585e-01 1.11124e+03]
# Time incubation: 0.004287897576728669 for column: [6.93599e-01 1.11331e+03]
# Time incubation: 0.004293585368087522 for column: [6.93614e-01 1.11406e+03]
# Time incubation: 0.004300202032705069 for column: [6.93628e-01 1.11391e+03]
# Time incubation: 0.004309002118144689 for column: [6.93642e-01 1.11242e+03]
# Time incubation: 0.004321164204649435 for column: [6.93656e-01 1.10958e+03]
# Time incubation: 0.004337476943123257 for column: [6.93670e-01 1.10592e+03]
# Time incubation: 0.004359837721953206 for column: [6.93684e-01 1.10197e+03]
# Time incubation: 0.004391327022605785 for column: [6.93698e-01 1.09770e+03]
# Time incubation: 0.0044353537375091834 for column: [6.93712e-01 1.09314e+03]
# Time incubation: 0.00447874342069412 for column: [6.93726e-01 1.08841e+03]
# Time incubation: 0.0045272712557152305 for column: [6.93737e-01 1.08489e+03]
# Time incubation: 0.004629493314284037 for column: [6.93747e-01 1.08141e+03]
# Time incubation: 0.004758698488074584 for column: [6.93763e-01 1.07626e+03]
# Time incubation: 0.004918164486204475 for column: [6.93779e-01 1.07119e+03]
# Time incubation: 0.005110643562274572 for column: [6.93795e-01 1.06620e+03]
# Time incubation: 0.005324000908982394 for column: [6.93811e-01 1.06127e+03]
# Time incubation: 0.005515852522896687 for column: [6.93826e-01 1.05641e+03]
# Time incubation: 0.0057301670759477156 for column: [6.93838e-01 1.05281e+03]
# Time incubation: 0.006104834102677144 for column: [6.93850e-01 1.04924e+03]
# Time incubation: 0.00653603979794444 for column: [6.93868e-01 1.04398e+03]
# Time incubation: 0.007027666065536108 for column: [6.93886e-01 1.03880e+03]
# Time incubation: 0.0075824665876054395 for column: [6.93904e-01 1.03370e+03]
# Time incubation: 0.00801786154651875 for column: [6.93922e-01 1.02868e+03]
# Time incubation: 0.008487883996778042 for column: [6.93935e-01 1.02497e+03]
# Time incubation: 0.009030481777967085 for column: [6.93948e-01 1.02129e+03]
# Time incubation: 0.00956690332203018 for column: [6.93962e-01 1.01766e+03]
# Time incubation: 0.010134205524863656 for column: [6.93975e-01 1.01407e+03]
# Time incubation: 0.010775931091160585 for column: [6.93988e-01 1.01051e+03]
# Time incubation: 0.011397960348988235 for column: [6.94002e-01 1.00700e+03]
# Time incubation: 0.012043652735700669 for column: [6.94015e-01 1.00353e+03]
# Time incubation: 0.01276204035105266 for column: [6.94028e-01 1.00010e+03]
# Time incubation: 0.013448220532023766 for column: [6.94042e-01 9.96704e+02]
# Time incubation: 0.014151081386319061 for column: [6.94055e-01 9.93347e+02]
# Time incubation: 0.014923280772963827 for column: [6.94068e-01 9.90029e+02]
# Time incubation: 0.015651981950684696 for column: [6.94082e-01 9.86747e+02]
# Time incubation: 0.01644664716359183 for column: [6.94095e-01 9.83503e+02]
# Time incubation: 0.017191406947015674 for column: [6.94109e-01 9.80294e+02]
# Time incubation: 0.01776715230760327 for column: [6.94122e-01 9.77122e+02]
# Time incubation: 0.01834487356854708 for column: [6.94132e-01 9.74763e+02]
# Time incubation: 0.019213636927198234 for column: [6.94142e-01 9.72423e+02]
# Time incubation: 0.020082008365715703 for column: [6.94157e-01 9.68958e+02]
# Time incubation: 0.020947540405541292 for column: [6.94172e-01 9.65536e+02]
# Time incubation: 0.02180794588143065 for column: [6.94187e-01 9.62157e+02]
# Time incubation: 0.022661123850072892 for column: [6.94202e-01 9.58820e+02]
# Time incubation: 0.02328188412511952 for column: [6.94217e-01 9.55524e+02]
# Time incubation: 0.023952944080149977 for column: [6.94228e-01 9.53075e+02]
# Time incubation: 0.02456181355828903 for column: [6.94240e-01 9.50648e+02]
# Time incubation: 0.025163837042895584 for column: [6.94251e-01 9.48244e+02]
# Time incubation: 0.025812529090413882 for column: [6.94262e-01 9.45863e+02]
# Time incubation: 0.026399234991289964 for column: [6.94274e-01 9.43503e+02]
# Time incubation: 0.02697747629696741 for column: [6.94285e-01 9.41165e+02]
# Time incubation: 0.027546732507718837 for column: [6.94296e-01 9.38848e+02]
# Time incubation: 0.028157395925546683 for column: [6.94307e-01 9.36552e+02]
# Time incubation: 0.028707220256340878 for column: [6.94319e-01 9.34277e+02]
# Time incubation: 0.02924666745490756 for column: [6.94330e-01 9.32022e+02]
# Time incubation: 0.03005525193003739 for column: [6.94341e-01 9.29788e+02]
# Time incubation: 0.030837637942434715 for column: [6.94358e-01 9.26481e+02]
# Time incubation: 0.03159297602939155 for column: [6.94375e-01 9.23219e+02]
# Time incubation: 0.032320697180450345 for column: [6.94392e-01 9.19999e+02]
# Time incubation: 0.033020500255114674 for column: [6.94409e-01 9.16822e+02]
# Time incubation: 0.033692304632501245 for column: [6.94426e-01 9.13688e+02]
# Time incubation: 0.03433605392313575 for column: [6.94443e-01 9.10594e+02]
# Time incubation: 0.034951497334903006 for column: [6.94460e-01 9.07541e+02]
# Time incubation: 0.03550383305665431 for column: [6.94477e-01 9.04527e+02]
# Time incubation: 0.036061884767423134 for column: [6.94493e-01 9.01553e+02]
# Time incubation: 0.03659106882714571 for column: [6.94510e-01 8.98617e+02]
# Time incubation: 0.03709153860430464 for column: [6.94527e-01 8.95718e+02]
# Time incubation: 0.03756367469411985 for column: [6.94544e-01 8.92856e+02]
# Time incubation: 0.03800810257666667 for column: [6.94561e-01 8.90030e+02]
# Time incubation: 0.03842569724484802 for column: [6.94578e-01 8.87240e+02]
# Time incubation: 0.038817507670270486 for column: [6.94595e-01 8.84486e+02]
# Time incubation: 0.039102922661376306 for column: [6.94612e-01 8.81765e+02]
# Time incubation: 0.039353781521095 for column: [6.94625e-01 8.79744e+02]
# Time incubation: 0.039722681165523056 for column: [6.94637e-01 8.77742e+02]
# Time incubation: 0.04006519915212164 for column: [6.94656e-01 8.74780e+02]
# Time incubation: 0.04038325390379034 for column: [6.94675e-01 8.71858e+02]
# Time incubation: 0.04067870161960534 for column: [6.94694e-01 8.68977e+02]
# Time incubation: 0.04089935556071072 for column: [6.94713e-01 8.66136e+02]
# Time incubation: 0.041094050617941795 for column: [6.94728e-01 8.64026e+02]
# Time incubation: 0.04127790790610374 for column: [6.94742e-01 8.61939e+02]
# Time incubation: 0.041451302407192 for column: [6.94756e-01 8.59873e+02]
# Time incubation: 0.041626250336703266 for column: [6.94770e-01 8.57829e+02]
# Time incubation: 0.041779785372522804 for column: [6.94785e-01 8.55805e+02]
# Time incubation: 0.04192395249363007 for column: [6.94799e-01 8.53801e+02]
# Time incubation: 0.042031900152708856 for column: [6.94813e-01 8.51818e+02]
# Time incubation: 0.04213470716466639 for column: [6.94824e-01 8.50341e+02]
# Time incubation: 0.04227360576092132 for column: [6.94835e-01 8.48876e+02]
# Time incubation: 0.04240265082232122 for column: [6.94851e-01 8.46702e+02]
# Time incubation: 0.04252268286765459 for column: [6.94867e-01 8.44552e+02]
# Time incubation: 0.042634539339278854 for column: [6.94883e-01 8.42426e+02]
# Time incubation: 0.04273901648324316 for column: [6.94899e-01 8.40324e+02]
# Time incubation: 0.04281358393601696 for column: [6.94915e-01 8.38245e+02]
# Time incubation: 0.04288465469068845 for column: [6.94927e-01 8.36698e+02]
# Time incubation: 0.0429841618473584 for column: [6.94939e-01 8.35164e+02]
# Time incubation: 0.0430773324133795 for column: [6.94957e-01 8.32891e+02]
# Time incubation: 0.04316455258937843 for column: [6.94975e-01 8.30645e+02]
# Time incubation: 0.043245916673350114 for column: [6.94993e-01 8.28425e+02]
# Time incubation: 0.043305761399767995 for column: [6.95011e-01 8.26232e+02]
# Time incubation: 0.04335811162220056 for column: [6.95025e-01 8.24602e+02]
# Time incubation: 0.043434875615822925 for column: [6.95038e-01 8.22985e+02]
# Time incubation: 0.04350065792907896 for column: [6.95059e-01 8.20593e+02]
# Time incubation: 0.043559388784094495 for column: [6.95079e-01 8.18232e+02]
# Time incubation: 0.04361415589321256 for column: [6.95099e-01 8.15901e+02]
# Time incubation: 0.04366051463231742 for column: [6.9512e-01 8.1360e+02]
# Time incubation: 0.043701946919318155 for column: [6.95140e-01 8.11328e+02]
# Time incubation: 0.04374114592046545 for column: [6.95160e-01 8.09085e+02]
# Time incubation: 0.043775105061697274 for column: [6.95181e-01 8.06870e+02]
# Time incubation: 0.04379898084463109 for column: [6.95201e-01 8.04683e+02]
# Time incubation: 0.04382145140378334 for column: [6.95216e-01 8.03058e+02]
# Time incubation: 0.04384403031852844 for column: [6.95231e-01 8.01448e+02]
# Time incubation: 0.04386394087991677 for column: [6.95247e-01 7.99854e+02]
# Time incubation: 0.043882610366315945 for column: [6.95262e-01 7.98274e+02]
# Time incubation: 0.043900041871755405 for column: [6.95277e-01 7.96709e+02]
# Time incubation: 0.043916240102213226 for column: [6.95292e-01 7.95158e+02]
# Time incubation: 0.04393221592679377 for column: [6.95307e-01 7.93622e+02]
# Time incubation: 0.04394600004518103 for column: [6.95323e-01 7.92099e+02]
# Time incubation: 0.043958637009055876 for column: [6.95338e-01 7.90591e+02]
# Time incubation: 0.04397020556201638 for column: [6.95353e-01 7.89096e+02]
# Time incubation: 0.04398150921529979 for column: [6.95368e-01 7.87615e+02]
# Time incubation: 0.043991236162029025 for column: [6.95384e-01 7.86148e+02]
# Time incubation: 0.04400019095840913 for column: [6.95399e-01 7.84694e+02]
# Time incubation: 0.04400846494999374 for column: [6.95414e-01 7.83253e+02]
# Time incubation: 0.044016651710011394 for column: [6.95429e-01 7.81826e+02]
# Time incubation: 0.04402380024505854 for column: [6.95445e-01 7.80412e+02]
# Time incubation: 0.044030486556493685 for column: [6.9546e-01 7.7901e+02]
# Time incubation: 0.04403676630512937 for column: [6.95475e-01 7.77622e+02]
# Time incubation: 0.044043079362146305 for column: [6.95490e-01 7.76246e+02]
# Time incubation: 0.044047232196303625 for column: [6.95506e-01 7.74884e+02]
# Time incubation: 0.04405156205654039 for column: [6.95517e-01 7.73869e+02]
# Time incubation: 0.04405726999117205 for column: [6.95529e-01 7.72861e+02]
# Time incubation: 0.044062544944268346 for column: [6.95546e-01 7.71365e+02]
# Time incubation: 0.04406738071183119 for column: [6.95563e-01 7.69886e+02]
# Time incubation: 0.04407177787453781 for column: [6.95580e-01 7.68423e+02]
# Time incubation: 0.04407574634878166 for column: [6.95597e-01 7.66976e+02]
# Time incubation: 0.04407930531609154 for column: [6.95614e-01 7.65545e+02]
# Time incubation: 0.04408248398512848 for column: [6.95631e-01 7.64130e+02]
# Time incubation: 0.04408549203190092 for column: [6.95648e-01 7.62729e+02]
# Time incubation: 0.044088041237839395 for column: [6.95666e-01 7.61344e+02]
# Time incubation: 0.04409034218205357 for column: [6.95683e-01 7.59974e+02]
# Time incubation: 0.04409197884514469 for column: [6.95700e-01 7.58618e+02]
# Time incubation: 0.044093507470448746 for column: [6.95713e-01 7.57609e+02]
# Time incubation: 0.0440948311033586 for column: [6.95726e-01 7.56607e+02]
# Time incubation: 0.04409618192462563 for column: [6.95738e-01 7.55614e+02]
# Time incubation: 0.044097459822763294 for column: [6.95751e-01 7.54628e+02]
# Time incubation: 0.044098673835560286 for column: [6.95764e-01 7.53649e+02]
# Time incubation: 0.04409983181772286 for column: [6.95777e-01 7.52678e+02]
# Time incubation: 0.04410094082213164 for column: [6.95790e-01 7.51713e+02]
# Time incubation: 0.04410200622770394 for column: [6.95803e-01 7.50756e+02]
# Time incubation: 0.04410295223826968 for column: [6.95816e-01 7.49806e+02]
# Time incubation: 0.044103937749549044 for column: [6.95828e-01 7.48863e+02]
# Time incubation: 0.04410488396107411 for column: [6.95841e-01 7.47926e+02]
# Time incubation: 0.044105790113532044 for column: [6.95854e-01 7.46996e+02]
# Time incubation: 0.04410665494222702 for column: [6.95867e-01 7.46073e+02]
# Time incubation: 0.04410747717487501 for column: [6.95880e-01 7.45155e+02]
# Time incubation: 0.04410825565852256 for column: [6.95893e-01 7.44244e+02]
# Time incubation: 0.044108989598800684 for column: [6.95906e-01 7.43339e+02]
# Time incubation: 0.0441096256322838 for column: [6.95919e-01 7.42440e+02]
# Time incubation: 0.04411058320730382 for column: [6.95931e-01 7.41546e+02]
# Time incubation: 0.0441113987940013 for column: [6.95951e-01 7.40219e+02]
# Time incubation: 0.0441121257483192 for column: [6.95970e-01 7.38904e+02]
# Time incubation: 0.04411277181335328 for column: [6.95989e-01 7.37602e+02]
# Time incubation: 0.044113602612929056 for column: [6.96008e-01 7.36310e+02]
# Time incubation: 0.04411460533801243 for column: [6.96037e-01 7.34399e+02]
# Time incubation: 0.04411574235164636 for column: [6.96081e-01 7.31584e+02]
# Time incubation: 0.044116936472915425 for column: [6.96146e-01 7.27468e+02]
# Time incubation: 0.04411772989420433 for column: [6.96244e-01 7.21519e+02]
# Time incubation: 0.04411814977032689 for column: [6.96390e-01 7.13135e+02]
# Time incubation: 0.044118295997223396 for column: [6.9661e-01 7.0113e+02]
# Time incubation: 0.0441183376290944 for column: [  0.696829 689.135   ]
# Time incubation: 0.044118352401348745 for column: [  0.697049 677.515   ]
# Time incubation: 0.044118357713440026 for column: [  0.697269 666.962   ]
# Time incubation: 0.04411835950924817 for column: [  0.697488 657.612   ]
# Time incubation: 0.044118360146291544 for column: [  0.697708 649.224   ]
# Time incubation: 0.04411836037569247 for column: [  0.697928 641.491   ]
# Time incubation: 0.044118360473713994 for column: [  0.698148 634.284   ]
# Time incubation: 0.04411836052437851 for column: [  0.698367 627.525   ]
# Time incubation: 0.04411836055418954 for column: [  0.698587 621.159   ]
# Time incubation: 0.04411836057828978 for column: [  0.698807 615.151   ]
# Time incubation: 0.04411836059330563 for column: [  0.699136 606.867   ]
# Time incubation: 0.044118360594719755 for column: [  0.710014 605.596   ]
# Time incubation: 0.04411836059715561 for column: [  0.710026 613.405   ]
# Time incubation: 0.044118360602715005 for column: [  0.710037 620.746   ]
# Time incubation: 0.04411836061653143 for column: [  0.710049 627.826   ]
# Time incubation: 0.04411836065235389 for column: [  0.710061 635.008   ]
# Time incubation: 0.04411836072407833 for column: [  0.710073 641.707   ]
# Time incubation: 0.04411836087782463 for column: [  0.710084 647.53    ]
# Time incubation: 0.044118361151891244 for column: [  0.710096 652.614   ]
# Time incubation: 0.04411836160824031 for column: [  0.710108 657.118   ]
# Time incubation: 0.04411836223878769 for column: [  0.71012 661.477  ]
# Time incubation: 0.044118363193793614 for column: [  0.710131 665.41    ]
# Time incubation: 0.04411836443057735 for column: [  0.710143 668.628   ]
# Time incubation: 0.04411836581344322 for column: [  0.710155 671.191   ]
# Time incubation: 0.044118367612973775 for column: [  0.710166 673.208   ]
# Time incubation: 0.044118369700934 for column: [  0.710178 675.042   ]
# Time incubation: 0.04411837202945342 for column: [  0.71019 676.618  ]
# Time incubation: 0.04411837432299427 for column: [  0.710202 677.783   ]
# Time incubation: 0.04411837692410622 for column: [  0.710213 678.548   ]
# Time incubation: 0.044118379596662885 for column: [  0.710225 678.958   ]
# Time incubation: 0.044118382311096056 for column: [  0.710237 679.242   ]
# Time incubation: 0.04411838479406768 for column: [  0.710249 679.404   ]
# Time incubation: 0.044118387449294784 for column: [  0.71026 679.382  ]
# Time incubation: 0.04411839000998333 for column: [  0.710272 679.174   ]
# Time incubation: 0.044118392464618864 for column: [  0.710284 678.793   ]
# Time incubation: 0.04411839461333909 for column: [  0.710296 678.345   ]
# Time incubation: 0.04411839684332406 for column: [  0.710307 677.854   ]
# Time incubation: 0.04411839895608106 for column: [  0.710319 677.321   ]
# Time incubation: 0.04411840094961086 for column: [  0.710331 676.744   ]
# Time incubation: 0.0441184026729004 for column: [  0.710343 676.125   ]
# Time incubation: 0.04411840444624826 for column: [  0.710354 675.503   ]
# Time incubation: 0.0441184061194462 for column: [  0.710366 674.888   ]
# Time incubation: 0.044118407698372546 for column: [  0.710378 674.28    ]
# Time incubation: 0.044118409064516875 for column: [  0.71039 673.678  ]
# Time incubation: 0.0441184104715986 for column: [  0.710401 673.083   ]
# Time incubation: 0.044118411800553196 for column: [  0.710413 672.495   ]
# Time incubation: 0.044118413056330595 for column: [  0.710425 671.915   ]
# Time incubation: 0.04411841414454171 for column: [  0.710437 671.344   ]
# Time incubation: 0.0441184152672182 for column: [  0.710448 670.781   ]
# Time incubation: 0.04411841632949507 for column: [  0.71046 670.225  ]
# Time incubation: 0.04411841733520981 for column: [  0.710472 669.677   ]
# Time incubation: 0.04411841820858509 for column: [  0.710484 669.137   ]
# Time incubation: 0.04411841911164322 for column: [  0.710495 668.605   ]
# Time incubation: 0.04411841996821376 for column: [  0.710507 668.079   ]
# Time incubation: 0.04411842078124466 for column: [  0.710519 667.561   ]
# Time incubation: 0.044118421489152404 for column: [  0.710531 667.05    ]
# Time incubation: 0.044118422223174796 for column: [  0.710542 666.546   ]
# Time incubation: 0.044118422921403576 for column: [  0.710554 666.048   ]
# Time incubation: 0.04411842358612971 for column: [  0.710566 665.557   ]
# Time incubation: 0.04411842416667931 for column: [  0.710578 665.073   ]
# Time incubation: 0.04411842477030608 for column: [  0.710589 664.596   ]
# Time incubation: 0.044118425345833205 for column: [  0.710601 664.124   ]
# Time incubation: 0.04411842584884792 for column: [  0.710613 663.659   ]
# Time incubation: 0.04411842637212136 for column: [  0.710624 663.199   ]
# Time incubation: 0.0441184268710403 for column: [  0.710636 662.746   ]
# Time incubation: 0.044118427346714166 for column: [  0.710648 662.298   ]
# Time incubation: 0.044118427762368205 for column: [  0.71066 661.856  ]
# Time incubation: 0.04411842819460404 for column: [  0.710671 661.419   ]
# Time incubation: 0.04411842860658535 for column: [  0.710683 660.988   ]
# Time incubation: 0.044118428999284774 for column: [  0.710695 660.562   ]
# Time incubation: 0.04411842934237172 for column: [  0.710707 660.142   ]
# Time incubation: 0.04411842969910965 for column: [  0.710718 659.726   ]
# Time incubation: 0.044118430039210295 for column: [  0.71073 659.315  ]
# Time incubation: 0.04411843036346871 for column: [  0.710742 658.91    ]
# Time incubation: 0.04411843064692703 for column: [  0.710754 658.509   ]
# Time incubation: 0.04411843094187003 for column: [  0.710765 658.113   ]
# Time incubation: 0.04411843122326797 for column: [  0.710777 657.721   ]
# Time incubation: 0.04411843149180799 for column: [  0.710789 657.334   ]
# Time incubation: 0.04411843172671583 for column: [  0.710801 656.952   ]
# Time incubation: 0.04411843197131603 for column: [  0.710812 656.573   ]
# Time incubation: 0.04411843220483695 for column: [  0.710824 656.199   ]
# Time incubation: 0.04411843242777882 for column: [  0.710836 655.83    ]
# Time incubation: 0.04411843262291196 for column: [  0.710848 655.464   ]
# Time incubation: 0.044118432826231506 for column: [  0.710859 655.102   ]
# Time incubation: 0.04411843302044234 for column: [  0.710871 654.745   ]
# Time incubation: 0.044118433205997974 for column: [  0.710883 654.391   ]
# Time incubation: 0.04411843336853486 for column: [  0.710895 654.041   ]
# Time incubation: 0.0441184335380477 for column: [  0.710906 653.694   ]
# Time incubation: 0.04411843370013994 for column: [  0.710918 653.352   ]
# Time incubation: 0.0441184338551971 for column: [  0.71093 653.013  ]
# Time incubation: 0.044118433991203646 for column: [  0.710942 652.678   ]
# Time incubation: 0.04411843413324117 for column: [  0.710953 652.346   ]
# Time incubation: 0.04411843426928187 for column: [  0.710965 652.018   ]
# Time incubation: 0.04411843439962841 for column: [  0.710977 651.694   ]
# Time incubation: 0.044118434514157846 for column: [  0.710989 651.373   ]
# Time incubation: 0.04411843463396897 for column: [  0.711 651.055]
# Time incubation: 0.044118434748926065 for column: [  0.711012 650.74    ]
# Time incubation: 0.04411843485006361 for column: [  0.711024 650.429   ]
# Time incubation: 0.04411843495601433 for column: [  0.711035 650.12    ]
# Time incubation: 0.04411843505779951 for column: [  0.711047 649.815   ]
# Time incubation: 0.04411843515560973 for column: [  0.711059 649.513   ]
# Time incubation: 0.04411843524181422 for column: [  0.711071 649.213   ]
# Time incubation: 0.04411843533225679 for column: [  0.711082 648.917   ]
# Time incubation: 0.04411843541927436 for column: [  0.711094 648.623   ]
# Time incubation: 0.04411843550302059 for column: [  0.711106 648.332   ]
# Time incubation: 0.044118435576943116 for column: [  0.711118 648.043   ]
# Time incubation: 0.04411843565461028 for column: [  0.711129 647.758   ]
# Time incubation: 0.04411843572944435 for column: [  0.711141 647.474   ]
# Time incubation: 0.04411843580157114 for column: [  0.711153 647.193   ]
# Time incubation: 0.044118435865315775 for column: [  0.711165 646.914   ]
# Time incubation: 0.04411843593239161 for column: [  0.711176 646.637   ]
# Time incubation: 0.044118435997112404 for column: [  0.711188 646.363   ]
# Time incubation: 0.04411843605957324 for column: [  0.7112 646.091 ]
# Time incubation: 0.04411843611485254 for column: [  0.711212 645.82    ]
# Time incubation: 0.04411843617308871 for column: [  0.711223 645.552   ]
# Time incubation: 0.044118436229337525 for column: [  0.711235 645.286   ]
# Time incubation: 0.04411843628367482 for column: [  0.711247 645.022   ]
# Time incubation: 0.04411843633179712 for column: [  0.711259 644.76    ]
# Time incubation: 0.044118436382521435 for column: [  0.71127 644.5    ]
# Time incubation: 0.044118436431530635 for column: [  0.711282 644.242   ]
# Time incubation: 0.04411843647889288 for column: [  0.711294 643.985   ]
# Time incubation: 0.04411843652084689 for column: [  0.711306 643.731   ]
# Time incubation: 0.044118436565077745 for column: [  0.711317 643.478   ]
# Time incubation: 0.044118436607826564 for column: [  0.711329 643.227   ]
# Time incubation: 0.04411843664914094 for column: [  0.711341 642.978   ]
# Time incubation: 0.04411843668575023 for column: [  0.711353 642.73    ]
# Time incubation: 0.04411843672435532 for column: [  0.711364 642.485   ]
# Time incubation: 0.04411843676167171 for column: [  0.711376 642.241   ]
# Time incubation: 0.044118436794740784 for column: [  0.711388 641.998   ]
# Time incubation: 0.044118436829621355 for column: [  0.711399 641.757   ]
# Time incubation: 0.044118436863351984 for column: [  0.711411 641.518   ]
# Time incubation: 0.04411843689597151 for column: [  0.711423 641.281   ]
# Time incubation: 0.04411843692488897 for column: [  0.711435 641.045   ]
# Time incubation: 0.04411843695540339 for column: [  0.711446 640.81    ]
# Time incubation: 0.044118436984925895 for column: [  0.711458 640.577   ]
# Time incubation: 0.04411843701348693 for column: [  0.71147 640.346  ]
# Time incubation: 0.04411843703882485 for column: [  0.711482 640.115   ]
# Time incubation: 0.044118437065578976 for column: [  0.711493 639.887   ]
# Time incubation: 0.04411843709147736 for column: [  0.711505 639.66    ]
# Time incubation: 0.04411843711655056 for column: [  0.711517 639.434   ]
# Time incubation: 0.044118437138808295 for column: [  0.711529 639.209   ]
# Time incubation: 0.04411843716232593 for column: [  0.71154 638.986  ]
# Time incubation: 0.0441184371851109 for column: [  0.711552 638.764   ]
# Time incubation: 0.04411843720718971 for column: [  0.711564 638.544   ]
# Time incubation: 0.0441184372268048 for column: [  0.711576 638.325   ]
# Time incubation: 0.0441184372475473 for column: [  0.711587 638.107   ]
# Time incubation: 0.044118437267660814 for column: [  0.711599 637.89    ]
# Time incubation: 0.04411843728716825 for column: [  0.711611 637.675   ]
# Time incubation: 0.04411843730451474 for column: [  0.711623 637.461   ]
# Time incubation: 0.0441184373228755 for column: [  0.711634 637.248   ]
# Time incubation: 0.04411843734069411 for column: [  0.711646 637.036   ]
# Time incubation: 0.04411843735799279 for column: [  0.711658 636.825   ]
# Time incubation: 0.044118437373388476 for column: [  0.71167 636.616  ]
# Time incubation: 0.04411843738970102 for column: [  0.711681 636.407   ]
# Time incubation: 0.044118437405548314 for column: [  0.711693 636.2     ]
# Time incubation: 0.04411843742094722 for column: [  0.711705 635.994   ]
# Time incubation: 0.04411843743466671 for column: [  0.711717 635.789   ]
# Time incubation: 0.04411843744921683 for column: [  0.711728 635.585   ]
# Time incubation: 0.044118437463365336 for column: [  0.71174 635.382  ]
# Time incubation: 0.04411843747712855 for column: [  0.711752 635.18    ]
# Time incubation: 0.044118437489402536 for column: [  0.711764 634.98    ]
# Time incubation: 0.04411843750243225 for column: [  0.711775 634.78    ]
# Time incubation: 0.04411843751511468 for column: [  0.711787 634.581   ]
# Time incubation: 0.0441184375274621 for column: [  0.711799 634.383   ]
# Time incubation: 0.044118437538484316 for column: [  0.711811 634.186   ]
# Time incubation: 0.044118437550196725 for column: [  0.711822 633.99    ]
# Time incubation: 0.04411843756160821 for column: [  0.711834 633.795   ]
# Time incubation: 0.04411843757180249 for column: [  0.711846 633.601   ]
# Time incubation: 0.044118437582643145 for column: [  0.711857 633.408   ]
# Time incubation: 0.044118437593213086 for column: [  0.711869 633.216   ]
# Time incubation: 0.04411843760352026 for column: [  0.711881 633.025   ]
# Time incubation: 0.044118437612737094 for column: [  0.711893 632.834   ]
# Time incubation: 0.04411843762254668 for column: [  0.711904 632.645   ]
# Time incubation: 0.04411843763211944 for column: [  0.711916 632.456   ]
# Time incubation: 0.04411843764146336 for column: [  0.711928 632.268   ]
# Time incubation: 0.0441184376498259 for column: [  0.71194 632.081  ]
# Time incubation: 0.04411843765873376 for column: [  0.711951 631.895   ]
# Time incubation: 0.04411843766743387 for column: [  0.711963 631.709   ]
# Time incubation: 0.04411843767593419 for column: [  0.711975 631.524   ]
# Time incubation: 0.0441184376835471 for column: [  0.711987 631.341   ]
# Time incubation: 0.044118437691664195 for column: [  0.711998 631.157   ]
# Time incubation: 0.04411843769959853 for column: [  0.71201 630.975  ]
# Time incubation: 0.04411843770735603 for column: [  0.712022 630.793   ]
# Time incubation: 0.04411843771431021 for column: [  0.712034 630.612   ]
# Time incubation: 0.04411843772173005 for column: [  0.712045 630.432   ]
# Time incubation: 0.044118437728988665 for column: [  0.712057 630.252   ]
# Time incubation: 0.0441184377360912 for column: [  0.712069 630.073   ]
# Time incubation: 0.044118437742463296 for column: [  0.712081 629.895   ]
# Time incubation: 0.04411843774926745 for column: [  0.712092 629.718   ]
# Time incubation: 0.04411843775592899 for column: [  0.712104 629.541   ]
# Time incubation: 0.04411843776245158 for column: [  0.712116 629.365   ]
# Time incubation: 0.0441184377683072 for column: [  0.712128 629.189   ]
# Time incubation: 0.04411843777456393 for column: [  0.712139 629.014   ]
# Time incubation: 0.04411843778069348 for column: [  0.712151 628.839   ]
# Time incubation: 0.04411843778669973 for column: [  0.712163 628.665   ]
# Time incubation: 0.04411843779209524 for column: [  0.712175 628.492   ]
# Time incubation: 0.04411843779786466 for column: [  0.712186 628.319   ]
# Time incubation: 0.04411843780352034 for column: [  0.712198 628.147   ]
# Time incubation: 0.04411843780906569 for column: [  0.71221 627.975  ]
# Time incubation: 0.04411843781405025 for column: [  0.712222 627.804   ]
# Time incubation: 0.04411843781938349 for column: [  0.712233 627.633   ]
# Time incubation: 0.04411843782461476 for column: [  0.712245 627.463   ]
# Time incubation: 0.04411843782974708 for column: [  0.712257 627.293   ]
# Time incubation: 0.044118437834363124 for column: [  0.712269 627.124   ]
# Time incubation: 0.044118437839305004 for column: [  0.71228 626.955  ]
# Time incubation: 0.044118437844155256 for column: [  0.712292 626.787   ]
# Time incubation: 0.04411843784851927 for column: [  0.712304 626.619   ]
# Time incubation: 0.0441184378531936 for column: [  0.712315 626.451   ]
# Time incubation: 0.04411843785778298 for column: [  0.712327 626.285   ]
# Time incubation: 0.04411843786228983 for column: [  0.712339 626.118   ]
# Time incubation: 0.04411843786634717 for column: [  0.712351 625.952   ]
# Time incubation: 0.04411843787069497 for column: [  0.712362 625.786   ]
# Time incubation: 0.04411843787496613 for column: [  0.712374 625.621   ]
# Time incubation: 0.0441184378791628 for column: [  0.712386 625.456   ]
# Time incubation: 0.04411843788294296 for column: [  0.712398 625.292   ]
# Time incubation: 0.0441184378869955 for column: [  0.712409 625.128   ]
# Time incubation: 0.04411843789097875 for column: [  0.712421 624.964   ]
# Time incubation: 0.044118437894894204 for column: [  0.712433 624.801   ]
# Time incubation: 0.04411843789842292 for column: [  0.712445 624.638   ]
# Time incubation: 0.044118437902207895 for column: [  0.712456 624.476   ]
# Time incubation: 0.044118437905929696 for column: [  0.712468 624.314   ]
# Time incubation: 0.04411843790959004 for column: [  0.71248 624.152  ]
# Time incubation: 0.04411843791288985 for column: [  0.712492 623.991   ]
# Time incubation: 0.044118437916431094 for column: [  0.712503 623.829   ]
# Time incubation: 0.04411843791991464 for column: [  0.712515 623.669   ]
# Time incubation: 0.044118437923342024 for column: [  0.712527 623.508   ]
# Time incubation: 0.04411843792643337 for column: [  0.712539 623.348   ]
# Time incubation: 0.04411843792975219 for column: [  0.71255 623.188  ]
# Time incubation: 0.044118437933018534 for column: [  0.712562 623.029   ]
# Time incubation: 0.044118437936233455 for column: [  0.712574 622.87    ]
# Time incubation: 0.044118437940681605 for column: [  0.712586 622.711   ]
# Time incubation: 0.04411843794528262 for column: [  0.712603 622.473   ]
# Time incubation: 0.04411843794952829 for column: [  0.712621 622.236   ]
# Time incubation: 0.044118437953921626 for column: [  0.712638 621.999   ]
# Time incubation: 0.044118437960055504 for column: [  0.712656 621.763   ]
# Time incubation: 0.04411843796902949 for column: [  0.712682 621.411   ]
# Time incubation: 0.044118437981536716 for column: [  0.712722 620.884   ]
# Time incubation: 0.04411843799821793 for column: [  0.712782 620.1     ]
# Time incubation: 0.04411843801963499 for column: [  0.712871 618.936   ]
# Time incubation: 0.04411843804581956 for column: [  0.713004 617.21    ]
# Time incubation: 0.04411843807524858 for column: [  0.713205 614.666   ]
# Time incubation: 0.04411843810546004 for column: [  0.713506 610.951   ]
# Time incubation: 0.04411843812671567 for column: [  0.713958 605.492   ]
# Time incubation: 0.04411843819287597 for column: [  0.693295 600.608   ]
# Time incubation: 0.044118445599630615 for column: [  0.693312 643.627   ]
# Time incubation: 0.044118494256037845 for column: [  0.693329 685.346   ]
# Time incubation: 0.04411890793425201 for column: [6.93341e-01 7.10244e+02]
# Time incubation: 0.044121151700631016 for column: [6.93354e-01 7.35581e+02]
# Time incubation: 0.04413462858712852 for column: [6.93366e-01 7.62729e+02]
# Time incubation: 0.0441844115009416 for column: [6.93379e-01 7.92815e+02]
# Time incubation: 0.04432274341894586 for column: [6.93391e-01 8.23776e+02]
# Time incubation: 0.044616149424138586 for column: [6.93404e-01 8.52843e+02]
# Time incubation: 0.045078455924153375 for column: [6.93417e-01 8.80888e+02]
# Time incubation: 0.045758000820429565 for column: [6.93429e-01 9.08751e+02]
# Time incubation: 0.046452638177772856 for column: [6.93442e-01 9.38002e+02]
# Time incubation: 0.04739402408276295 for column: [6.93454e-01 9.65386e+02]
# Time incubation: 0.04795995178215646 for column: [6.93473e-01 1.00034e+03]
# Time incubation: 0.048203857250089584 for column: [6.93492e-01 1.03014e+03]
# Time incubation: 0.048312857748129184 for column: [6.93510e-01 1.05786e+03]
# Time incubation: 0.04835446945423668 for column: [6.93529e-01 1.07837e+03]
# Time incubation: 0.048375138378802474 for column: [6.93543e-01 1.08924e+03]
# Time incubation: 0.04838682532698573 for column: [6.93557e-01 1.09875e+03]
# Time incubation: 0.048394289794732176 for column: [6.93571e-01 1.10641e+03]
# Time incubation: 0.04840033246559253 for column: [6.93585e-01 1.11124e+03]
# Time incubation: 0.048406335703444325 for column: [6.93599e-01 1.11331e+03]
# Time incubation: 0.048412023494803176 for column: [6.93614e-01 1.11406e+03]
# Time incubation: 0.048418640159420726 for column: [6.93628e-01 1.11391e+03]
# Time incubation: 0.04842744024486034 for column: [6.93642e-01 1.11242e+03]
# Time incubation: 0.048439602331365086 for column: [6.93656e-01 1.10958e+03]
# Time incubation: 0.04845591506983891 for column: [6.93670e-01 1.10592e+03]
# Time incubation: 0.04847827584866886 for column: [6.93684e-01 1.10197e+03]
# Time incubation: 0.04850976514932144 for column: [6.93698e-01 1.09770e+03]
# Time incubation: 0.048553791864224836 for column: [6.93712e-01 1.09314e+03]
# Time incubation: 0.048597181547409773 for column: [6.93726e-01 1.08841e+03]
# Time incubation: 0.04864570938243088 for column: [6.93737e-01 1.08489e+03]
# Time incubation: 0.04874793144099969 for column: [6.93747e-01 1.08141e+03]
# Time incubation: 0.048877136614790234 for column: [6.93763e-01 1.07626e+03]
# Time incubation: 0.04903660261292012 for column: [6.93779e-01 1.07119e+03]
# Time incubation: 0.04922908168899022 for column: [6.93795e-01 1.06620e+03]
# Time incubation: 0.04944243903569804 for column: [6.93811e-01 1.06127e+03]
# Time incubation: 0.049634290649612334 for column: [6.93826e-01 1.05641e+03]
# Time incubation: 0.04984860520266336 for column: [6.93838e-01 1.05281e+03]
# Time incubation: 0.05022327222939279 for column: [6.93850e-01 1.04924e+03]
# Time incubation: 0.05065447792466009 for column: [6.93868e-01 1.04398e+03]
# Time incubation: 0.051146104192251754 for column: [6.93886e-01 1.03880e+03]
# Time incubation: 0.05170090471432109 for column: [6.93904e-01 1.03370e+03]
# Time incubation: 0.052136299673234396 for column: [6.93922e-01 1.02868e+03]
# Time incubation: 0.05260632212349369 for column: [6.93935e-01 1.02497e+03]
# Time incubation: 0.053148919904682734 for column: [6.93948e-01 1.02129e+03]
# Time incubation: 0.05368534144874583 for column: [6.93962e-01 1.01766e+03]
# Time incubation: 0.05425264365157931 for column: [6.93975e-01 1.01407e+03]
# Time incubation: 0.054894369217876236 for column: [6.93988e-01 1.01051e+03]
# Time incubation: 0.05551639847570389 for column: [6.94002e-01 1.00700e+03]
# Time incubation: 0.056162090862416324 for column: [6.94015e-01 1.00353e+03]
# Time incubation: 0.056880478477768316 for column: [6.94028e-01 1.00010e+03]
# Time incubation: 0.057566658658739424 for column: [6.94042e-01 9.96704e+02]
# Time incubation: 0.05826951951303472 for column: [6.94055e-01 9.93347e+02]
# Time incubation: 0.059041718899679484 for column: [6.94068e-01 9.90029e+02]
# Time incubation: 0.059770420077400355 for column: [6.94082e-01 9.86747e+02]
# Time incubation: 0.060565085290307484 for column: [6.94095e-01 9.83503e+02]
# Time incubation: 0.06130984507373133 for column: [6.94109e-01 9.80294e+02]
# Time incubation: 0.061885590434318925 for column: [6.94122e-01 9.77122e+02]
# Time incubation: 0.06246331169526273 for column: [6.94132e-01 9.74763e+02]
# Time incubation: 0.06333207505391389 for column: [6.94142e-01 9.72423e+02]
# Time incubation: 0.06420044649243135 for column: [6.94157e-01 9.68958e+02]
# Time incubation: 0.06506597853225694 for column: [6.94172e-01 9.65536e+02]
# Time incubation: 0.06592638400814631 for column: [6.94187e-01 9.62157e+02]
# Time incubation: 0.06677956197678855 for column: [6.94202e-01 9.58820e+02]
# Time incubation: 0.06740032225183518 for column: [6.94217e-01 9.55524e+02]
# Time incubation: 0.06807138220686564 for column: [6.94228e-01 9.53075e+02]
# Time incubation: 0.06868025168500469 for column: [6.94240e-01 9.50648e+02]
# Time incubation: 0.06928227516961125 for column: [6.94251e-01 9.48244e+02]
# Time incubation: 0.06993096721712955 for column: [6.94262e-01 9.45863e+02]
# Time incubation: 0.07051767311800562 for column: [6.94274e-01 9.43503e+02]
# Time incubation: 0.07109591442368307 for column: [6.94285e-01 9.41165e+02]
# Time incubation: 0.07166517063443449 for column: [6.94296e-01 9.38848e+02]
# Time incubation: 0.07227583405226233 for column: [6.94307e-01 9.36552e+02]
# Time incubation: 0.07282565838305652 for column: [6.94319e-01 9.34277e+02]
# Time incubation: 0.07336510558162321 for column: [6.94330e-01 9.32022e+02]
# Time incubation: 0.07417369005675303 for column: [6.94341e-01 9.29788e+02]
# Time incubation: 0.07495607606915036 for column: [6.94358e-01 9.26481e+02]
# Time incubation: 0.07571141415610719 for column: [6.94375e-01 9.23219e+02]
# Time incubation: 0.07643913530716598 for column: [6.94392e-01 9.19999e+02]
# Time incubation: 0.07713893838183031 for column: [6.94409e-01 9.16822e+02]
# Time incubation: 0.07781074275921687 for column: [6.94426e-01 9.13688e+02]
# Time incubation: 0.07845449204985137 for column: [6.94443e-01 9.10594e+02]
# Time incubation: 0.07906993546161863 for column: [6.94460e-01 9.07541e+02]
# Time incubation: 0.07962227118336994 for column: [6.94477e-01 9.04527e+02]
# Time incubation: 0.08018032289413876 for column: [6.94493e-01 9.01553e+02]
# Time incubation: 0.08070950695386134 for column: [6.94510e-01 8.98617e+02]
# Time incubation: 0.08120997673102026 for column: [6.94527e-01 8.95718e+02]
# Time incubation: 0.08168211282083547 for column: [6.94544e-01 8.92856e+02]
# Time incubation: 0.08212654070338228 for column: [6.94561e-01 8.90030e+02]
# Time incubation: 0.08254413537156363 for column: [6.94578e-01 8.87240e+02]
# Time incubation: 0.0829359457969861 for column: [6.94595e-01 8.84486e+02]
# Time incubation: 0.08322136078809192 for column: [6.94612e-01 8.81765e+02]
# Time incubation: 0.08347221964781061 for column: [6.94625e-01 8.79744e+02]
# Time incubation: 0.08384111929223867 for column: [6.94637e-01 8.77742e+02]
# Time incubation: 0.08418363727883725 for column: [6.94656e-01 8.74780e+02]
# Time incubation: 0.08450169203050595 for column: [6.94675e-01 8.71858e+02]
# Time incubation: 0.08479713974632094 for column: [6.94694e-01 8.68977e+02]
# Time incubation: 0.08501779368742633 for column: [6.94713e-01 8.66136e+02]
# Time incubation: 0.08521248874465741 for column: [6.94728e-01 8.64026e+02]
# Time incubation: 0.08539634603281936 for column: [6.94742e-01 8.61939e+02]
# Time incubation: 0.08556974053390762 for column: [6.94756e-01 8.59873e+02]
# Time incubation: 0.08574468846341889 for column: [6.94770e-01 8.57829e+02]
# Time incubation: 0.08589822349923842 for column: [6.94785e-01 8.55805e+02]
# Time incubation: 0.08604239062034569 for column: [6.94799e-01 8.53801e+02]
# Time incubation: 0.08615033827942448 for column: [6.94813e-01 8.51818e+02]
# Time incubation: 0.086253145291382 for column: [6.94824e-01 8.50341e+02]
# Time incubation: 0.08639204388763692 for column: [6.94835e-01 8.48876e+02]
# Time incubation: 0.08652108894903683 for column: [6.94851e-01 8.46702e+02]
# Time incubation: 0.0866411209943702 for column: [6.94867e-01 8.44552e+02]
# Time incubation: 0.08675297746599446 for column: [6.94883e-01 8.42426e+02]
# Time incubation: 0.08685745460995876 for column: [6.94899e-01 8.40324e+02]
# Time incubation: 0.08693202206273257 for column: [6.94915e-01 8.38245e+02]
# Time incubation: 0.08700309281740405 for column: [6.94927e-01 8.36698e+02]
# Time incubation: 0.08710259997407399 for column: [6.94939e-01 8.35164e+02]
# Time incubation: 0.0871957705400951 for column: [6.94957e-01 8.32891e+02]
# Time incubation: 0.08728299071609402 for column: [6.94975e-01 8.30645e+02]
# Time incubation: 0.08736435480006571 for column: [6.94993e-01 8.28425e+02]
# Time incubation: 0.08742419952648359 for column: [6.95011e-01 8.26232e+02]
# Time incubation: 0.08747654974891615 for column: [6.95025e-01 8.24602e+02]
# Time incubation: 0.08755331374253851 for column: [6.95038e-01 8.22985e+02]
# Time incubation: 0.08761909605579454 for column: [6.95059e-01 8.20593e+02]
# Time incubation: 0.08767782691081008 for column: [6.95079e-01 8.18232e+02]
# Time incubation: 0.08773259401992815 for column: [6.95099e-01 8.15901e+02]
# Time incubation: 0.08777895275903301 for column: [6.9512e-01 8.1360e+02]
# Time incubation: 0.08782038504603375 for column: [6.95140e-01 8.11328e+02]
# Time incubation: 0.08785958404718104 for column: [6.95160e-01 8.09085e+02]
# Time incubation: 0.08789354318841287 for column: [6.95181e-01 8.06870e+02]
# Time incubation: 0.08791741897134668 for column: [6.95201e-01 8.04683e+02]
# Time incubation: 0.08793988953049893 for column: [6.95216e-01 8.03058e+02]
# Time incubation: 0.08796246844524402 for column: [6.95231e-01 8.01448e+02]
# Time incubation: 0.08798237900663235 for column: [6.95247e-01 7.99854e+02]
# Time incubation: 0.08800104849303153 for column: [6.95262e-01 7.98274e+02]
# Time incubation: 0.08801847999847098 for column: [6.95277e-01 7.96709e+02]
# Time incubation: 0.0880346782289288 for column: [6.95292e-01 7.95158e+02]
# Time incubation: 0.08805065405350934 for column: [6.95307e-01 7.93622e+02]
# Time incubation: 0.0880644381718966 for column: [6.95323e-01 7.92099e+02]
# Time incubation: 0.08807707513577145 for column: [6.95338e-01 7.90591e+02]
# Time incubation: 0.08808864368873195 for column: [6.95353e-01 7.89096e+02]
# Time incubation: 0.08809994734201536 for column: [6.95368e-01 7.87615e+02]
# Time incubation: 0.0881096742887446 for column: [6.95384e-01 7.86148e+02]
# Time incubation: 0.0881186290851247 for column: [6.95399e-01 7.84694e+02]
# Time incubation: 0.08812690307670931 for column: [6.95414e-01 7.83253e+02]
# Time incubation: 0.08813508983672697 for column: [6.95429e-01 7.81826e+02]
# Time incubation: 0.08814223837177411 for column: [6.95445e-01 7.80412e+02]
# Time incubation: 0.08814892468320926 for column: [6.9546e-01 7.7901e+02]
# Time incubation: 0.08815520443184494 for column: [6.95475e-01 7.77622e+02]
# Time incubation: 0.08816151748886186 for column: [6.95490e-01 7.76246e+02]
# Time incubation: 0.08816567032301918 for column: [6.95506e-01 7.74884e+02]
# Time incubation: 0.08817000018325595 for column: [6.95517e-01 7.73869e+02]
# Time incubation: 0.08817570811788761 for column: [6.95529e-01 7.72861e+02]
# Time incubation: 0.0881809830709839 for column: [6.95546e-01 7.71365e+02]
# Time incubation: 0.08818581883854675 for column: [6.95563e-01 7.69886e+02]
# Time incubation: 0.08819021600125337 for column: [6.95580e-01 7.68423e+02]
# Time incubation: 0.08819418447549723 for column: [6.95597e-01 7.66976e+02]
# Time incubation: 0.08819774344280712 for column: [6.95614e-01 7.65545e+02]
# Time incubation: 0.08820092211184406 for column: [6.95631e-01 7.64130e+02]
# Time incubation: 0.08820393015861651 for column: [6.95648e-01 7.62729e+02]
# Time incubation: 0.08820647936455499 for column: [6.95666e-01 7.61344e+02]
# Time incubation: 0.08820878030876916 for column: [6.95683e-01 7.59974e+02]
# Time incubation: 0.08821041697186027 for column: [6.95700e-01 7.58618e+02]
# Time incubation: 0.08821194559716433 for column: [6.95713e-01 7.57609e+02]
# Time incubation: 0.08821326923007419 for column: [6.95726e-01 7.56607e+02]
# Time incubation: 0.08821462005134122 for column: [6.95738e-01 7.55614e+02]
# Time incubation: 0.08821589794947887 for column: [6.95751e-01 7.54628e+02]
# Time incubation: 0.08821711196227587 for column: [6.95764e-01 7.53649e+02]
# Time incubation: 0.08821826994443845 for column: [6.95777e-01 7.52678e+02]
# Time incubation: 0.08821937894884722 for column: [6.95790e-01 7.51713e+02]
# Time incubation: 0.08822044435441953 for column: [6.95803e-01 7.50756e+02]
# Time incubation: 0.08822139036498527 for column: [6.95816e-01 7.49806e+02]
# Time incubation: 0.08822237587626464 for column: [6.95828e-01 7.48863e+02]
# Time incubation: 0.0882233220877897 for column: [6.95841e-01 7.47926e+02]
# Time incubation: 0.08822422824024764 for column: [6.95854e-01 7.46996e+02]
# Time incubation: 0.08822509306894262 for column: [6.95867e-01 7.46073e+02]
# Time incubation: 0.08822591530159062 for column: [6.95880e-01 7.45155e+02]
# Time incubation: 0.08822669378523817 for column: [6.95893e-01 7.44244e+02]
# Time incubation: 0.0882274277255163 for column: [6.95906e-01 7.43339e+02]
# Time incubation: 0.08822806375899941 for column: [6.95919e-01 7.42440e+02]
# Time incubation: 0.08822902133401944 for column: [6.95931e-01 7.41546e+02]
# Time incubation: 0.08822983692071691 for column: [6.95951e-01 7.40219e+02]
# Time incubation: 0.0882305638750348 for column: [6.95970e-01 7.38904e+02]
# Time incubation: 0.08823120994006889 for column: [6.95989e-01 7.37602e+02]
# Time incubation: 0.08823204073964466 for column: [6.96008e-01 7.36310e+02]
# Time incubation: 0.08823304346472804 for column: [6.96037e-01 7.34399e+02]
# Time incubation: 0.08823418047836197 for column: [6.96081e-01 7.31584e+02]
# Time incubation: 0.08823537459963103 for column: [6.96146e-01 7.27468e+02]
# Time incubation: 0.08823616802091994 for column: [6.96244e-01 7.21519e+02]
# Time incubation: 0.08823658789704249 for column: [6.96390e-01 7.13135e+02]
# Time incubation: 0.088236734123939 for column: [6.9661e-01 7.0113e+02]
# Time incubation: 0.08823677575581 for column: [  0.696829 689.135   ]
# Time incubation: 0.08823679052806435 for column: [  0.697049 677.515   ]
# Time incubation: 0.08823679584015563 for column: [  0.697269 666.962   ]
# Time incubation: 0.08823679763596377 for column: [  0.697488 657.612   ]
# Time incubation: 0.08823679827300715 for column: [  0.697708 649.224   ]
# Time incubation: 0.08823679850240808 for column: [  0.697928 641.491   ]
# Time incubation: 0.0882367986004296 for column: [  0.698148 634.284   ]
# Time incubation: 0.08823679865109411 for column: [  0.698367 627.525   ]
# Time incubation: 0.08823679868090514 for column: [  0.698587 621.159   ]
# Time incubation: 0.08823679870500539 for column: [  0.698807 615.151   ]
# Time incubation: 0.08823679872002124 for column: [  0.699136 606.867   ]
# Time incubation: 0.08823679872143537 for column: [  0.710014 605.596   ]
# Time incubation: 0.08823679872387123 for column: [  0.710026 613.405   ]
# Time incubation: 0.08823679872943063 for column: [  0.710037 620.746   ]
# Time incubation: 0.08823679874324707 for column: [  0.710049 627.826   ]
# Time incubation: 0.08823679877906952 for column: [  0.710061 635.008   ]
# Time incubation: 0.08823679885079397 for column: [  0.710073 641.707   ]
# Time incubation: 0.08823679900454026 for column: [  0.710084 647.53    ]
# Time incubation: 0.08823679927860688 for column: [  0.710096 652.614   ]
# Time incubation: 0.08823679973495593 for column: [  0.710108 657.118   ]
# Time incubation: 0.08823680036550331 for column: [  0.71012 661.477  ]
# Time incubation: 0.08823680132050923 for column: [  0.710131 665.41    ]
# Time incubation: 0.08823680255729298 for column: [  0.710143 668.628   ]
# Time incubation: 0.08823680394015886 for column: [  0.710155 671.191   ]
# ...
# Time incubation: 0.4411843075710173 for column: [  0.710143 668.628   ]
# Time incubation: 0.44118430895388316 for column: [  0.710155 671.191   ]
# Time incubation: 0.44118431075341374 for column: [  0.710166 673.208   ]
# Time incubation: 0.441184312841374 for column: [  0.710178 675.042   ]
# Time incubation: 0.4411843151698934 for column: [  0.71019 676.618  ]
# Time incubation: 0.4411843174634343 for column: [  0.710202 677.783   ]
# Time incubation: 0.4411843200645462 for column: [  0.710213 678.548   ]
# Time incubation: 0.4411843227371029 for column: [  0.710225 678.958   ]
# Time incubation: 0.4411843254515361 for column: [  0.710237 679.242   ]
# Time incubation: 0.4411843279345077 for column: [  0.710249 679.404   ]
# Time incubation: 0.4411843305897348 for column: [  0.71026 679.382  ]
# Time incubation: 0.4411843331504233 for column: [  0.710272 679.174   ]
# Time incubation: 0.4411843356050589 for column: [  0.710284 678.793   ]
# Time incubation: 0.4411843377537791 for column: [  0.710296 678.345   ]
# Time incubation: 0.44118433998376405 for column: [  0.710307 677.854   ]
# Time incubation: 0.441184342096521 for column: [  0.710319 677.321   ]
# Time incubation: 0.4411843440900508 for column: [  0.710331 676.744   ]
# Time incubation: 0.4411843458133404 for column: [  0.710343 676.125   ]
# Time incubation: 0.44118434758668823 for column: [  0.710354 675.503   ]
# Time incubation: 0.44118434925988614 for column: [  0.710366 674.888   ]
# Time incubation: 0.44118435083881247 for column: [  0.710378 674.28    ]
# Time incubation: 0.4411843522049568 for column: [  0.71039 673.678  ]
# Time incubation: 0.4411843536120385 for column: [  0.710401 673.083   ]
# Time incubation: 0.4411843549409931 for column: [  0.710413 672.495   ]
# Time incubation: 0.4411843561967705 for column: [  0.710425 671.915   ]
# Time incubation: 0.4411843572849816 for column: [  0.710437 671.344   ]
# Time incubation: 0.44118435840765813 for column: [  0.710448 670.781   ]
# Time incubation: 0.441184359469935 for column: [  0.71046 670.225  ]
# Time incubation: 0.44118436047564974 for column: [  0.710472 669.677   ]
# Time incubation: 0.441184361349025 for column: [  0.710484 669.137   ]
# Time incubation: 0.44118436225208313 for column: [  0.710495 668.605   ]
# Time incubation: 0.44118436310865367 for column: [  0.710507 668.079   ]
# Time incubation: 0.4411843639216846 for column: [  0.710519 667.561   ]
# Time incubation: 0.4411843646295923 for column: [  0.710531 667.05    ]
# Time incubation: 0.4411843653636147 for column: [  0.710542 666.546   ]
# Time incubation: 0.44118436606184347 for column: [  0.710554 666.048   ]
# Time incubation: 0.4411843667265696 for column: [  0.710566 665.557   ]
# Time incubation: 0.4411843673071192 for column: [  0.710578 665.073   ]
# Time incubation: 0.44118436791074594 for column: [  0.710589 664.596   ]
# Time incubation: 0.44118436848627307 for column: [  0.710601 664.124   ]
# Time incubation: 0.44118436898928776 for column: [  0.710613 663.659   ]
# Time incubation: 0.4411843695125612 for column: [  0.710624 663.199   ]
# Time incubation: 0.44118437001148014 for column: [  0.710636 662.746   ]
# Time incubation: 0.44118437048715403 for column: [  0.710648 662.298   ]
# Time incubation: 0.44118437090280804 for column: [  0.71066 661.856  ]
# Time incubation: 0.4411843713350439 for column: [  0.710671 661.419   ]
# Time incubation: 0.44118437174702524 for column: [  0.710683 660.988   ]
# Time incubation: 0.44118437213972467 for column: [  0.710695 660.562   ]
# Time incubation: 0.4411843724828116 for column: [  0.710707 660.142   ]
# Time incubation: 0.44118437283954953 for column: [  0.710718 659.726   ]
# Time incubation: 0.4411843731796502 for column: [  0.71073 659.315  ]
# Time incubation: 0.4411843735039086 for column: [  0.710742 658.91    ]
# Time incubation: 0.4411843737873669 for column: [  0.710754 658.509   ]
# Time incubation: 0.4411843740823099 for column: [  0.710765 658.113   ]
# Time incubation: 0.4411843743637079 for column: [  0.710777 657.721   ]
# Time incubation: 0.4411843746322479 for column: [  0.710789 657.334   ]
# Time incubation: 0.4411843748671557 for column: [  0.710801 656.952   ]
# Time incubation: 0.4411843751117559 for column: [  0.710812 656.573   ]
# Time incubation: 0.4411843753452768 for column: [  0.710824 656.199   ]
# Time incubation: 0.4411843755682187 for column: [  0.710836 655.83    ]
# Time incubation: 0.44118437576335184 for column: [  0.710848 655.464   ]
# Time incubation: 0.44118437596667137 for column: [  0.710859 655.102   ]
# Time incubation: 0.4411843761608822 for column: [  0.710871 654.745   ]
# Time incubation: 0.4411843763464378 for column: [  0.710883 654.391   ]
# Time incubation: 0.4411843765089747 for column: [  0.710895 654.041   ]
# Time incubation: 0.44118437667848753 for column: [  0.710906 653.694   ]
# Time incubation: 0.44118437684057976 for column: [  0.710918 653.352   ]
# Time incubation: 0.4411843769956369 for column: [  0.71093 653.013  ]
# Time incubation: 0.44118437713164343 for column: [  0.710942 652.678   ]
# Time incubation: 0.441184377273681 for column: [  0.710953 652.346   ]
# Time incubation: 0.44118437740972166 for column: [  0.710965 652.018   ]
# Time incubation: 0.4411843775400682 for column: [  0.710977 651.694   ]
# Time incubation: 0.4411843776545976 for column: [  0.710989 651.373   ]
# Time incubation: 0.4411843777744087 for column: [  0.711 651.055]
# Time incubation: 0.4411843778893658 for column: [  0.711012 650.74    ]
# Time incubation: 0.44118437799050336 for column: [  0.711024 650.429   ]
# Time incubation: 0.4411843780964541 for column: [  0.711035 650.12    ]
# Time incubation: 0.4411843781982393 for column: [  0.711047 649.815   ]
# Time incubation: 0.4411843782960495 for column: [  0.711059 649.513   ]
# Time incubation: 0.441184378382254 for column: [  0.711071 649.213   ]
# Time incubation: 0.44118437847269654 for column: [  0.711082 648.917   ]
# Time incubation: 0.4411843785597141 for column: [  0.711094 648.623   ]
# Time incubation: 0.44118437864346033 for column: [  0.711106 648.332   ]
# Time incubation: 0.44118437871738286 for column: [  0.711118 648.043   ]
# Time incubation: 0.44118437879505 for column: [  0.711129 647.758   ]
# Time incubation: 0.4411843788698841 for column: [  0.711141 647.474   ]
# Time incubation: 0.4411843789420109 for column: [  0.711153 647.193   ]
# Time incubation: 0.4411843790057555 for column: [  0.711165 646.914   ]
# Time incubation: 0.44118437907283137 for column: [  0.711176 646.637   ]
# Time incubation: 0.44118437913755215 for column: [  0.711188 646.363   ]
# Time incubation: 0.44118437920001297 for column: [  0.7112 646.091 ]
# Time incubation: 0.44118437925529225 for column: [  0.711212 645.82    ]
# Time incubation: 0.4411843793135284 for column: [  0.711223 645.552   ]
# Time incubation: 0.4411843793697772 for column: [  0.711235 645.286   ]
# Time incubation: 0.44118437942411454 for column: [  0.711247 645.022   ]
# Time incubation: 0.4411843794722368 for column: [  0.711259 644.76    ]
# Time incubation: 0.44118437952296113 for column: [  0.71127 644.5    ]
# Time incubation: 0.4411843795719703 for column: [  0.711282 644.242   ]
# Time incubation: 0.44118437961933255 for column: [  0.711294 643.985   ]
# Time incubation: 0.44118437966128654 for column: [  0.711306 643.731   ]
# Time incubation: 0.4411843797055174 for column: [  0.711317 643.478   ]
# Time incubation: 0.4411843797482662 for column: [  0.711329 643.227   ]
# Time incubation: 0.4411843797895806 for column: [  0.711341 642.978   ]
# Time incubation: 0.44118437982618985 for column: [  0.711353 642.73    ]
# Time incubation: 0.441184379864795 for column: [  0.711364 642.485   ]
# Time incubation: 0.44118437990211135 for column: [  0.711376 642.241   ]
# Time incubation: 0.4411843799351804 for column: [  0.711388 641.998   ]
# Time incubation: 0.44118437997006094 for column: [  0.711399 641.757   ]
# Time incubation: 0.44118438000379157 for column: [  0.711411 641.518   ]
# Time incubation: 0.4411843800364111 for column: [  0.711423 641.281   ]
# Time incubation: 0.44118438006532856 for column: [  0.711435 641.045   ]
# Time incubation: 0.441184380095843 for column: [  0.711446 640.81    ]
# Time incubation: 0.4411843801253655 for column: [  0.711458 640.577   ]
# Time incubation: 0.4411843801539265 for column: [  0.71147 640.346  ]
# Time incubation: 0.4411843801792644 for column: [  0.711482 640.115   ]
# Time incubation: 0.4411843802060185 for column: [  0.711493 639.887   ]
# Time incubation: 0.4411843802319169 for column: [  0.711505 639.66    ]
# Time incubation: 0.44118438025699014 for column: [  0.711517 639.434   ]
# Time incubation: 0.4411843802792479 for column: [  0.711529 639.209   ]
# Time incubation: 0.4411843803027655 for column: [  0.71154 638.986  ]
# Time incubation: 0.4411843803255505 for column: [  0.711552 638.764   ]
# Time incubation: 0.44118438034762936 for column: [  0.711564 638.544   ]
# Time incubation: 0.44118438036724444 for column: [  0.711576 638.325   ]
# Time incubation: 0.44118438038798696 for column: [  0.711587 638.107   ]
# Time incubation: 0.4411843804081005 for column: [  0.711599 637.89    ]
# Time incubation: 0.44118438042760794 for column: [  0.711611 637.675   ]
# Time incubation: 0.44118438044495445 for column: [  0.711623 637.461   ]
# Time incubation: 0.4411843804633152 for column: [  0.711634 637.248   ]
# Time incubation: 0.4411843804811338 for column: [  0.711646 637.036   ]
# Time incubation: 0.44118438049843245 for column: [  0.711658 636.825   ]
# Time incubation: 0.44118438051382813 for column: [  0.71167 636.616  ]
# Time incubation: 0.4411843805301407 for column: [  0.711681 636.407   ]
# Time incubation: 0.441184380545988 for column: [  0.711693 636.2     ]
# Time incubation: 0.4411843805613869 for column: [  0.711705 635.994   ]
# Time incubation: 0.4411843805751064 for column: [  0.711717 635.789   ]
# Time incubation: 0.44118438058965653 for column: [  0.711728 635.585   ]
# Time incubation: 0.44118438060380505 for column: [  0.71174 635.382  ]
# Time incubation: 0.44118438061756826 for column: [  0.711752 635.18    ]
# Time incubation: 0.4411843806298423 for column: [  0.711764 634.98    ]
# Time incubation: 0.44118438064287196 for column: [  0.711775 634.78    ]
# Time incubation: 0.4411843806555544 for column: [  0.711787 634.581   ]
# Time incubation: 0.4411843806679018 for column: [  0.711799 634.383   ]
# Time incubation: 0.441184380678924 for column: [  0.711811 634.186   ]
# Time incubation: 0.4411843806906364 for column: [  0.711822 633.99    ]
# Time incubation: 0.4411843807020479 for column: [  0.711834 633.795   ]
# Time incubation: 0.4411843807122422 for column: [  0.711846 633.601   ]
# Time incubation: 0.44118438072308286 for column: [  0.711857 633.408   ]
# Time incubation: 0.4411843807336528 for column: [  0.711869 633.216   ]
# Time incubation: 0.44118438074396 for column: [  0.711881 633.025   ]
# Time incubation: 0.44118438075317684 for column: [  0.711893 632.834   ]
# Time incubation: 0.44118438076298644 for column: [  0.711904 632.645   ]
# Time incubation: 0.44118438077255917 for column: [  0.711916 632.456   ]
# Time incubation: 0.4411843807819031 for column: [  0.711928 632.268   ]
# Time incubation: 0.4411843807902656 for column: [  0.71194 632.081  ]
# Time incubation: 0.4411843807991735 for column: [  0.711951 631.895   ]
# Time incubation: 0.4411843808078736 for column: [  0.711963 631.709   ]
# Time incubation: 0.4411843808163739 for column: [  0.711975 631.524   ]
# Time incubation: 0.4411843808239868 for column: [  0.711987 631.341   ]
# Time incubation: 0.44118438083210393 for column: [  0.711998 631.157   ]
# Time incubation: 0.44118438084003825 for column: [  0.71201 630.975  ]
# Time incubation: 0.44118438084779577 for column: [  0.712022 630.793   ]
# Time incubation: 0.4411843808547499 for column: [  0.712034 630.612   ]
# Time incubation: 0.44118438086216977 for column: [  0.712045 630.432   ]
# Time incubation: 0.4411843808694284 for column: [  0.712057 630.252   ]
# Time incubation: 0.44118438087653095 for column: [  0.712069 630.073   ]
# Time incubation: 0.441184380882903 for column: [  0.712081 629.895   ]
# Time incubation: 0.4411843808897072 for column: [  0.712092 629.718   ]
# Time incubation: 0.44118438089636874 for column: [  0.712104 629.541   ]
# Time incubation: 0.44118438090289136 for column: [  0.712116 629.365   ]
# Time incubation: 0.441184380908747 for column: [  0.712128 629.189   ]
# Time incubation: 0.4411843809150037 for column: [  0.712139 629.014   ]
# Time incubation: 0.44118438092113327 for column: [  0.712151 628.839   ]
# Time incubation: 0.4411843809271395 for column: [  0.712163 628.665   ]
# Time incubation: 0.44118438093253504 for column: [  0.712175 628.492   ]
# Time incubation: 0.4411843809383045 for column: [  0.712186 628.319   ]
# Time incubation: 0.4411843809439602 for column: [  0.712198 628.147   ]
# Time incubation: 0.4411843809495055 for column: [  0.71221 627.975  ]
# Time incubation: 0.4411843809544901 for column: [  0.712222 627.804   ]
# Time incubation: 0.4411843809598233 for column: [  0.712233 627.633   ]
# Time incubation: 0.4411843809650546 for column: [  0.712245 627.463   ]
# Time incubation: 0.4411843809701869 for column: [  0.712257 627.293   ]
# Time incubation: 0.44118438097480295 for column: [  0.712269 627.124   ]
# Time incubation: 0.44118438097974483 for column: [  0.71228 626.955  ]
# Time incubation: 0.44118438098459506 for column: [  0.712292 626.787   ]
# Time incubation: 0.44118438098895907 for column: [  0.712304 626.619   ]
# Time incubation: 0.4411843809936334 for column: [  0.712315 626.451   ]
# Time incubation: 0.44118438099822277 for column: [  0.712327 626.285   ]
# Time incubation: 0.4411843810027296 for column: [  0.712339 626.118   ]
# Time incubation: 0.441184381006787 for column: [  0.712351 625.952   ]
# Time incubation: 0.4411843810111348 for column: [  0.712362 625.786   ]
# Time incubation: 0.4411843810154059 for column: [  0.712374 625.621   ]
# Time incubation: 0.44118438101960256 for column: [  0.712386 625.456   ]
# Time incubation: 0.4411843810233827 for column: [  0.712398 625.292   ]
# Time incubation: 0.44118438102743524 for column: [  0.712409 625.128   ]
# Time incubation: 0.4411843810314185 for column: [  0.712421 624.964   ]
# Time incubation: 0.4411843810353339 for column: [  0.712433 624.801   ]
# Time incubation: 0.44118438103886265 for column: [  0.712445 624.638   ]
# Time incubation: 0.4411843810426476 for column: [  0.712456 624.476   ]
# Time incubation: 0.4411843810463694 for column: [  0.712468 624.314   ]
# Time incubation: 0.4411843810500298 for column: [  0.71248 624.152  ]
# Time incubation: 0.4411843810533296 for column: [  0.712492 623.991   ]
# Time incubation: 0.4411843810568708 for column: [  0.712503 623.829   ]
# Time incubation: 0.44118438106035435 for column: [  0.712515 623.669   ]
# Time incubation: 0.4411843810637817 for column: [  0.712527 623.508   ]
# Time incubation: 0.4411843810668731 for column: [  0.712539 623.348   ]
# Time incubation: 0.4411843810701919 for column: [  0.71255 623.188  ]
# Time incubation: 0.44118438107345825 for column: [  0.712562 623.029   ]
# Time incubation: 0.4411843810766732 for column: [  0.712574 622.87    ]
# Time incubation: 0.44118438108112135 for column: [  0.712586 622.711   ]
# Time incubation: 0.44118438108572233 for column: [  0.712603 622.473   ]
# Time incubation: 0.441184381089968 for column: [  0.712621 622.236   ]
# Time incubation: 0.4411843810943613 for column: [  0.712638 621.999   ]
# Time incubation: 0.4411843811004952 for column: [  0.712656 621.763   ]
# Time incubation: 0.44118438110946917 for column: [  0.712682 621.411   ]
# Time incubation: 0.4411843811219764 for column: [  0.712722 620.884   ]
# Time incubation: 0.4411843811386576 for column: [  0.712782 620.1     ]
# Time incubation: 0.4411843811600747 for column: [  0.712871 618.936   ]
# Time incubation: 0.44118438118625924 for column: [  0.713004 617.21    ]
# Time incubation: 0.44118438121568826 for column: [  0.713205 614.666   ]
# Time incubation: 0.4411843812458997 for column: [  0.713506 610.951   ]
# Time incubation: 0.4411843812671553 for column: [  0.713958 605.492   ]

# %%
a = 1.2
mag = a if a < 1 else 1
mag
# Out:
# 1

# %%
fcr
# Out:
# 0.0

# %%
transformation_time_read(0, 3.562952343304009e-29, 3.2923472615096365)

# %%
fig1,ax1 = plt.subplots()
ax.plot(time,fcr)
ax.set_xlabel('Time(s)')
ax.set_ylabel('Volume fraction')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-f8b5f884202e> in <module>()
#       1 fig1,ax1 = plt.subplots()
# ----> 2 ax.plot(time,fcr)
#       3 ax.set_xlabel('Time(s)')
#       4 ax.set_ylabel('Volume fraction')
#
# ~\Anaconda2\envs\idp\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda2\envs\idp\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1526         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1527
# -> 1528         for line in self._get_lines(*args, **kwargs):
#    1529             self.add_line(line)
#    1530             lines.append(line)
#
# ~\Anaconda2\envs\idp\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# ~\Anaconda2\envs\idp\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# ~\Anaconda2\envs\idp\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (2379,) and (1,)
